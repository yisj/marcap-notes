# %%
# 우량주 분석
import datetime
# today=  datetime.datetime.now()
today = datetime.datetime.strptime('2021-11-05', '%Y-%m-%d')

first = '1995-05-02'

y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-11-05'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\jae\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\jae\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
d = df5

# %%
wuryang = d[d['Dept'] == '우량기업부']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 615

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# C:\Users\jae\AppData\Local\Temp/ipykernel_9488/4028455208.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
data[0]
# Out:
# ['068270',
#  '셀트리온',
#  74472.27867348492,
#  394908.663294743,
#  206270.33523192554,
#  74451.79123083752,
#  209000.0,
#  0.9869394030235672,
#  0.5146233522186008]

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C', 'Cdf']
wdf = pd.DataFrame(data, columns=['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C', 'Cdf'])
wdf['C/M'] = 1 / wdf['M/C']
wdf['Max/Current'] = wdf['Max']/wdf['Current']
wdf.sort_values(['Cdf'], ascending=[True]).to_csv('wuryang-%s.csv' % today)
wdf.sort_values(['Cdf'], ascending=[True]).head(60)
# Out:
#        Code      Name       Min       Max      Mean       Std   Current  M/C  \
# 169  049520      유아이엘   2595.00   8200.00   5087.03   1200.86   2645.00 1.92
# 331  043200        파루    960.26   4416.22   2203.25    571.95   1095.00 2.01
# 117  038060       루멘스    925.00   5307.24   2695.81    967.44    925.00 2.91
# 565  330350     위더스제약   8600.00  22933.33  13660.34   1821.42  10350.00 1.32
# 545  262260      에이프로  30400.00  53700.00  39443.06   4146.71  32200.00 1.22
# 231  099440        스맥   1082.51   3853.91   2554.90    622.92   1565.00 1.63
# 211  088910   동우팜투테이블   2010.00   5010.00   3718.44    437.12   3050.00 1.22
# 505  289010   아이스크림에듀   6160.00  13300.00   8561.18   1073.03   6930.00 1.24
# 501  100590       머큐리   4490.00  15100.00  10017.28   1363.58   8020.00 1.25
# 299  037950       엘컴텍   1225.00   3015.00   1922.95    382.02   1365.00 1.41
# 531  204270     제이앤티씨   4900.00  14950.00  10747.59   1729.99   8230.00 1.31
# 194  111870   KH 일렉트론    331.54   2438.30   1207.64    301.98    778.00 1.55
# 74   122990       와이솔   7456.03  18090.37  13043.89   1862.78  10400.00 1.25
# 385  214430   아이쓰리시스템  10398.46  29200.00  20461.03   2489.97  16950.00 1.21
# 351  067080      대화제약   5815.03  33431.52  17920.52   5876.70   9790.00 1.83
# 573  290520      신도기연  14100.00  26950.00  18904.98   2630.85  15350.00 1.23
# 590  195940     HK이노엔  49750.00  69600.00  61117.80   4228.12  55500.00 1.10
# 2    086900      메디톡스 100255.18 771914.97 364609.15 163999.90 153700.00 2.37
# 354  217480   에스디생명공학   2360.00  22098.79   8507.15   4268.26   3110.00 2.74
# 352  049960     쎌바이오텍  10050.00  52100.00  27659.52  10491.55  18800.00 1.47
# 232  011560     세보엠이씨   3350.00  17300.00   8899.20   2759.97   6570.00 1.35
# 145  015710        코콤   3085.00  10050.00   7342.67   1140.07   6390.00 1.15
# 47   168330    내츄럴엔도텍   1681.68  20650.70   9554.21   4741.00   5600.00 1.71
# 61   078150   HB테크놀러지   1635.00   5994.83   3237.51    920.86   2470.00 1.31
# 362  067390       아스트   2738.31  13852.73   8019.12   2209.59   6190.00 1.30
# 245  081580      성우전자   1280.00   5550.00   3488.66    919.92   2755.00 1.27
# 7    036830   솔브레인홀딩스  18836.47  89713.23  47798.42  12937.15  37500.00 1.27
#
#      Cdf  C/M  Max/Current
# 169 0.02 0.52         3.10
# 331 0.03 0.50         4.03
# 117 0.03 0.34         5.74
# 565 0.03 0.76         2.22
# 545 0.04 0.82         1.67
# 231 0.06 0.61         2.46
# 211 0.06 0.82         1.64
# 505 0.06 0.81         1.92
# 501 0.07 0.80         1.88
# 299 0.07 0.71         2.21
# 531 0.07 0.77         1.82
# 194 0.08 0.64         3.13
# 74  0.08 0.80         1.74
# 385 0.08 0.83         1.72
# 351 0.08 0.55         3.41
# 573 0.09 0.81         1.76
# 590 0.09 0.91         1.25
# 2   0.10 0.42         5.02
# 354 0.10 0.37         7.11
# 315 0.10 0.56         3.66
# 454 0.10 0.37         5.56
# 80  0.11 0.52         3.15
# 15  0.11 0.49         4.10
# 142 0.12 0.81         1.98
# 440 0.12 0.31         8.99
# 585 0.12 0.86         1.71
# 188 0.12 0.64         2.67
# 422 0.12 0.70         2.20
# 540 0.13 0.76         2.12
# 508 0.14 0.77         2.34
# 284 0.14 0.53         4.37
# 518 0.15 0.60         3.11
# 173 0.15 0.62         2.70
# 359 0.15 0.79         1.99
# 353 0.15 0.40         5.83
# 65  0.16 0.82         1.87
# 179 0.16 0.77         2.11
# 72  0.16 0.74         2.31
# 360 0.16 0.74         2.23
# 552 0.16 0.84         1.94
# 150 0.17 0.70         2.69
# 12  0.17 0.80         2.21
# 516 0.17 0.81         1.87
# 347 0.17 0.90         1.46
# 125 0.18 0.85         1.66
# 278 0.18 0.54         4.44
# 200 0.19 0.90         1.57
# 343 0.20 0.49         5.95
# 292 0.20 0.43         9.51
# 337 0.20 0.84         1.81
# 187 0.20 0.59         3.73
# 483 0.20 0.73         3.16
# 352 0.20 0.68         2.77
# 232 0.20 0.74         2.63
# 145 0.20 0.87         1.57
# 47  0.20 0.59         3.69
# 61  0.20 0.76         2.43
# 362 0.20 0.77         2.24
# 245 0.21 0.79         2.01
# 7   0.21 0.78         2.39

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']

# %%
df[df['Code'] == '054950'].iloc[-1]

# %%
wdf[wdf[1]=="파루"]
