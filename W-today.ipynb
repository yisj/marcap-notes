# %%
# 우량주 분석
import datetime
# today=  datetime.datetime.now()
today = datetime.datetime.strptime('2021-03-29', '%Y-%m-%d')

first = '1995-05-02'

y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-29'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
d = df5

# %%
wuryang = d[d['Dept'] == '우량기업부']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 567

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-11-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf['Max/Current'] = wdf[3]/wdf[6]
wdf.sort_values([8], ascending=[True]).to_csv('wuryang-%s.csv' % today)
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0          1         2         3         4         5         6    7  \
# 358  043200         파루   1160.00   4759.95   2550.29    475.84   1320.00 1.93
# 75   016250   SGC이테크건설  49350.00 279755.13 182952.80  57119.15  51900.00 3.53
# 187  046070        코다코    974.00   3840.00   2602.90    791.69   1220.00 2.13
# 455  006620    동구바이오제약  10750.00  43850.00  22289.62   6729.73  10750.00 2.07
# 213  099440         스맥   1082.51   3853.91   2668.23    573.57   1730.00 1.54
# 330  037950        엘컴텍   1225.00   3866.74   2053.98    419.57   1375.00 1.49
# 109  038060        루멘스   1001.93   5307.24   3031.68    912.45   1730.00 1.75
# 263  086900       메디톡스 104900.00 807677.76 409307.35 156333.13 191300.00 2.14
# 95   026040     제이에스티나   1390.00  16000.00   6483.07   3253.89   2075.00 3.12
# 9    102940    코오롱생명과학  11200.00 127177.66  62441.26  31939.80  19700.00 3.17
# 26   016100    리더스코스메틱   2128.07  33536.23  12974.29   7506.31   3430.00 3.78
# 344  234920        자이글   1650.00  13050.00   6844.92   2378.05   3830.00 1.79
# 452  260930  씨티케이코스메틱스   8850.00  46000.00  21035.55   8716.59  10100.00 2.08
# 384  255440         야스   7510.00  31141.71  19424.12   5035.48  13150.00 1.48
# 235  039310         세중   1100.00   5250.00   3434.78    714.78   2545.00 1.35
# 120  053980      오상자이엘   5350.00  18100.00   9146.97   2068.47   6620.00 1.38
# 194  040420    정상제이엘에스   5440.00   8450.00   7155.89    604.91   6440.00 1.11
# 76   035810      이지홀딩스   2321.65   9869.61   6052.56   1183.90   4665.00 1.30
# 202  009300       삼아제약   9860.00  31750.00  18257.81   2983.87  14800.00 1.23
# 462  227610     아우딘퓨쳐스   1165.00  13850.00   5417.87   2928.56   2065.00 2.62
# 305  014200         광림   1425.00   8018.59   3312.78   1472.90   1650.00 2.01
# 400  225190      삼양옵틱스   7497.99  19717.22  13494.95   3112.75  10000.00 1.35
# 376  067080       대화제약   5815.03  46990.13  21074.96   8295.94  11800.00 1.79
# 288  039980        리노스    731.20   4696.59   2122.18    856.70   1175.00 1.81
# 316  090470       제이스텍   5230.00  28450.00  12881.92   5241.35   7140.00 1.80
#
#        8  C/M  Max/Current
# 358 0.00 0.52         3.61
# 75  0.01 0.28         5.39
# 187 0.04 0.47         3.15
# 455 0.04 0.48         4.08
# 213 0.05 0.65         2.23
# 330 0.05 0.67         2.81
# 109 0.08 0.57         3.07
# 263 0.08 0.47         4.22
# 95  0.09 0.32         7.71
# 9   0.09 0.32         6.46
# 26  0.10 0.26         9.78
# 344 0.10 0.56         3.41
# 452 0.10 0.48         4.55
# 384 0.11 0.68         2.37
# 235 0.11 0.74         2.06
# 120 0.11 0.72         2.73
# 194 0.12 0.90         1.31
# 76  0.12 0.77         2.12
# 202 0.12 0.81         2.15
# 462 0.13 0.38         6.71
# 305 0.13 0.50         4.86
# 400 0.13 0.74         1.97
# 376 0.13 0.56         3.98
# 288 0.13 0.55         4.00
# 316 0.14 0.55         3.98
# 293 0.14 0.69         2.56
# 318 0.14 0.77         1.93
# 476 0.15 0.80         2.11
# 157 0.15 0.79         1.95
# 378 0.15 0.52         4.65
# 154 0.16 0.84         1.61
# 129 0.16 0.81         1.73
# 311 0.16 0.47         4.89
# 377 0.16 0.58         3.53
# 61  0.17 0.82         1.76
# 323 0.17 0.39         9.03
# 124 0.18 0.75         2.18
# 89  0.18 0.91         1.35
# 231 0.18 0.72         2.70
# 386 0.18 0.75         2.18
# 106 0.19 0.85         1.68
# 313 0.19 0.79         1.95
# 281 0.19 0.80         2.12
# 168 0.19 0.53         4.40
# 199 0.20 0.70         2.52
# 364 0.20 0.36         7.25
# 467 0.20 0.72         2.85
# 492 0.21 0.80         2.59
# 80  0.21 0.87         1.71
# 197 0.22 0.91         1.45
# 74  0.22 0.83         1.85
# 21  0.22 0.76         2.46
# 345 0.22 0.85         1.92
# 15  0.22 0.83         1.84
# 70  0.22 0.68         2.71
# 412 0.22 0.71         3.44
# 483 0.23 0.80         2.99
# 504 0.23 0.84         1.89
# 41  0.23 0.71         2.73
# 375 0.24 0.76         2.43

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 9340.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 13050.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-29 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       37700.0
# ChangeCode                        1
# Changes                       100.0
# ChagesRatio                     NaN
# Open                        37100.0
# High                        37800.0
# Low                         37050.0
# Volume                      74471.0
# Amount                 2788435600.0
# Marcap               238675231600.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            864
# ChangesRatio                   0.27
# Name: 11214866, dtype: object

# %%
wdf[wdf[1]=="파루"]
# Out:
#           0   1       2       3       4      5       6    7    8  C/M  \
# 358  043200  파루 1160.00 4759.95 2550.29 475.84 1320.00 1.93 0.00 0.52
#
#      Max/Current
# 358         3.61
