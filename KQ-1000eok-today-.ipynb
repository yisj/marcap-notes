# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)

y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')

y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-15'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df4

# %%
w = d[d['Market'] == 'KOSDAQ']
wuryang = w[w['Marcap'] > 1000000000000]

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 103

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#          0           1         2         3         4         5         6    7  \
# 3   041960         코미팜  10000.00  38530.73  21855.31   7669.81  10400.00 2.10
# 7   084990       헬릭스미스  14450.76 145379.85  71259.28  33025.51  24100.00 2.96
# 2   086900        메디톡스 104900.00 807677.76 414214.88 172657.88 205100.00 2.02
# 17  102940     코오롱생명과학  11200.00 127177.66  55644.11  30934.31  18800.00 2.96
# 44  038540         상상인   4750.00  27357.14  11853.14   5375.94   6440.00 1.84
# 42  115450      지트리비앤티  12912.71  47158.66  25238.01   6273.67  18950.00 1.33
# 65  084850     아이티엠반도체  24333.46  71176.95  53207.67   9673.19  43550.00 1.22
# 6   028150       GS홈쇼핑  88600.00 245200.00 172482.72  36601.97 143500.00 1.20
# 50  214370         케어젠  54000.00 101900.00  74060.19   9484.15  66700.00 1.11
# 49  049950       미래컴퍼니  10761.84 150476.01  57753.96  31404.39  33600.00 1.72
# 19  108230          톱텍   7209.59  34158.70  17772.80   7624.45  12100.00 1.47
# 26  051370       인터플렉스   7160.00  63524.61  20060.09  12244.30  11750.00 1.71
# 34  028300       에이치엘비   8630.13 136698.44  58504.93  30896.56  39800.00 1.47
# 41  200230      텔콘RF제약   3057.57  15994.16   6643.62   2549.36   5160.00 1.29
# 48  041510         에스엠  16696.15  55050.24  34643.86   7648.92  30250.00 1.15
# 20  036830     솔브레인홀딩스  18836.47  89713.23  49744.69  13749.95  42350.00 1.17
# 22  003380        하림지주   3694.04  14589.03  10173.48   2424.40   8910.00 1.14
# 47  042000        카페24  10264.40  96917.97  41495.76  19192.67  32150.00 1.29
# 55  025980         아난티   3815.94  30104.87   9657.81   4483.58   7750.00 1.25
# 56  298380     에이비엘바이오  12709.72  36686.54  23548.01   6073.40  21650.00 1.09
# 43  078160       메디포스트  18287.18  79723.56  36676.11  10287.44  34000.00 1.08
# 67  060250  NHN한국사이버결제   9082.24  73500.00  25866.27  19379.48  47200.00 0.55
# 63  082270         젬백스   7805.06  39615.13  16210.04   7227.56  24300.00 0.67
# 37  095700         제넥신  26234.20 179201.21  68606.04  30181.95 102700.00 0.67
# 53  035900    JYP Ent.   5054.07  43250.00  23153.26   9463.76  34300.00 0.68
# 12  039030      이오테크닉스  38029.46 126200.00  81392.54  19544.02 106600.00 0.76
# 46  000250       삼천당제약  11796.61  88600.00  36283.69  14893.50  55700.00 0.65
# 35  200130     콜마비앤에이치  16250.00  71900.00  32200.61  12420.06  48900.00 0.66
#
#       8  C/M
# 3  0.07 0.48
# 7  0.08 0.34
# 2  0.11 0.50
# 17 0.12 0.34
# 44 0.16 0.54
# 42 0.16 0.75
# 65 0.16 0.82
# 6  0.21 0.83
# 50 0.22 0.90
# 49 0.22 0.58
# 19 0.23 0.68
# 26 0.25 0.59
# 34 0.27 0.68
# 41 0.28 0.78
# 48 0.28 0.87
# 20 0.30 0.85
# 22 0.30 0.88
# 47 0.31 0.77
# 55 0.34 0.80
# 56 0.38 0.92
# 43 0.40 0.93
# 18 0.40 0.96
# 62 0.41 0.86
# 40 0.44 0.90
# 16 0.48 0.99
# 51 0.48 0.97
# 24 0.49 0.97
# 87 0.54 1.01
# 9  0.56 1.07
# 10 0.58 1.04
# 39 0.61 1.08
# 84 0.67 1.22
# 69 0.69 1.26
# 11 0.72 1.12
# 8  0.74 1.07
# 52 0.75 1.16
# 80 0.78 1.57
# 61 0.79 1.38
# 89 0.80 1.50
# 14 0.80 1.18
# 85 0.81 1.47
# 21 0.81 1.97
# 28 0.81 1.22
# 15 0.82 1.21
# 83 0.83 1.83
# 5  0.83 1.19
# 38 0.84 1.16
# 57 0.86 1.61
# 64 0.86 1.68
# 82 0.86 2.29
# 59 0.86 1.90
# 0  0.86 1.37
# 73 0.86 1.43
# 67 0.86 1.82
# 63 0.87 1.50
# 37 0.87 1.50
# 53 0.88 1.48
# 12 0.90 1.31
# 46 0.90 1.54
# 35 0.91 1.52

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8910.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-15 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36300.0
# ChangeCode                        1
# Changes                       150.0
# ChagesRatio                     NaN
# Open                        36500.0
# High                        36550.0
# Low                         36100.0
# Volume                      48136.0
# Amount                 1747864300.0
# Marcap               229811960400.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            862
# ChangesRatio                   0.41
# Name: 11190491, dtype: object
