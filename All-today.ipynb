# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'

y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-17'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
d = df1

# %%
wuryang = d[d["Market"] != "KONEX"]

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 2410

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-11-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in double_scalars
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).to_csv('all-%s.csv' % today)
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#            0          1         2         3         4        5         6    7  \
# 46    028300      에이치엘비  39800.00 119285.02  88256.18 11267.42  42250.00 2.09
# 385   245620       EDGC   5260.00  17560.52  11409.38  2294.93   5260.00 2.17
# 824   038340        UCI    781.00   3130.25   2385.94   604.05    781.00 3.05
# 1113  043200         파루   1403.49   3120.00   2517.96   426.73   1500.00 1.68
# 2210  326030     SK바이오팜 104000.00 217000.00 163310.34 22121.93 111500.00 1.46
# 2222  347890       엠투아이  10600.00  23050.00  16254.19  2402.53  10750.00 1.51
# 81    000210         DL  61000.00 219510.56 169604.79 41104.13  78000.00 2.17
# 159   067630  에이치엘비생명과학  11850.00  34485.35  22148.85  4203.19  13100.00 1.69
# 759   006620    동구바이오제약  10900.00  41500.00  22640.65  5118.11  11700.00 1.94
# 611   095270    웨이브일렉트로   2750.00  11039.34   6432.65  1662.84   3040.00 2.12
# 2212  290520       신도기연  16200.00  26950.00  20969.48  1870.74  17200.00 1.22
# 456   040350        큐로컴   1380.00   2590.02   2018.18   286.86   1450.00 1.39
# 910   000215        DL우  37000.00 127559.51  83034.18 21908.31  39850.00 2.08
# 1011  061250       화일약품   3095.88  16650.00   9691.84  2365.14   5230.00 1.85
# 2177  001529      동양3우B  19450.00  38950.00  28667.89  2445.19  24100.00 1.19
# 1030  049520       유아이엘   3485.00   4360.00   3951.77   191.47   3600.00 1.10
# 435   228760      지노믹트리  11600.00  21300.00  16487.20  2314.87  12300.00 1.34
# 2028  099410       동방선기    965.00   4850.00   3106.53   850.71   1600.00 1.94
# 981   060560     홈센타홀딩스    896.00   1535.00   1171.04   138.27    933.00 1.26
# 1069  033340      좋은사람들   1030.00   2560.00   1717.82   381.28   1075.00 1.60
# 649   053980      오상자이엘   6450.00  18100.00  10642.68  2302.77   6800.00 1.57
# 2225  332570        와이팜  10050.00  18800.00  13864.05  1741.55  11050.00 1.25
# 327   230240      에치에프알  18600.00  39577.25  30056.50  4139.44  24750.00 1.21
# 923   083550        케이엠   8344.93  21500.00  15171.54  3148.32  11150.00 1.36
# 2278  354200      엔젠바이오  15350.00  36355.51  23565.37  5688.84  16300.00 1.45
# 639   042520    한스바이오메드  11100.00  26666.81  17677.23  4421.93  12100.00 1.46
# 353   078070    유비쿼스홀딩스  12550.00  39950.00  28530.08  4610.11  22750.00 1.25
#
#         8  C/M
# 46   0.00 0.48
# 385  0.00 0.46
# 824  0.00 0.33
# 1113 0.01 0.60
# 2210 0.01 0.68
# 2222 0.01 0.66
# 81   0.01 0.46
# 159  0.02 0.59
# 759  0.02 0.52
# 611  0.02 0.47
# 2212 0.02 0.82
# 456  0.02 0.72
# 910  0.02 0.48
# 1011 0.03 0.54
# 2177 0.03 0.84
# 1030 0.03 0.91
# 435  0.04 0.75
# 2028 0.04 0.52
# 981  0.04 0.80
# 1069 0.05 0.63
# 649  0.05 0.64
# 2225 0.05 0.80
# 1769 0.05 0.47
# 807  0.06 0.79
# 1650 0.06 0.85
# 579  0.06 0.64
# 346  0.06 0.66
# 1503 0.06 0.69
# 1518 0.06 0.67
# 2276 0.07 0.75
# 2274 0.07 0.78
# 1712 0.07 0.75
# 821  0.07 0.84
# 1091 0.07 0.84
# 2072 0.07 0.83
# 1156 0.08 0.92
# 2260 0.08 0.88
# 153  0.08 0.82
# 661  0.08 0.84
# 2236 0.08 0.82
# 2168 0.08 0.68
# 2313 0.08 0.90
# 2270 0.08 0.84
# 2200 0.09 0.78
# 604  0.09 0.85
# 818  0.09 0.85
# 2280 0.09 0.84
# 231  0.09 0.59
# 864  0.09 0.42
# 1187 0.09 0.77
# 117  0.09 0.69
# 2211 0.09 0.86
# 246  0.10 0.82
# 817  0.10 0.83
# 2163 0.10 0.86
# 327  0.10 0.82
# 923  0.10 0.73
# 2278 0.10 0.69
# 639  0.10 0.68
# 353  0.10 0.80

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8930.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12650.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-17 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36500.0
# ChangeCode                        1
# Changes                       300.0
# ChagesRatio                     NaN
# Open                        36550.0
# High                        36650.0
# Low                         36000.0
# Volume                      30184.0
# Amount                 1097527900.0
# Marcap               231078142000.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            873
# ChangesRatio                   0.83
# Name: 11195385, dtype: object

# %%
wdf[wdf[1]=="파루"]
# Out:
#            0   1       2       3       4      5       6    7    8  C/M
# 1113  043200  파루 1403.49 3120.00 2517.96 426.73 1500.00 1.68 0.01 0.60
