# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)

y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')

y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-15'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df6

# %%
w = d[d['Market'] == 'KOSPI']
wuryang = w[w['Marcap'] > 5000000000000]

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 97

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#          0            1         2         3         4         5         6  \
# 81  326030       SK바이오팜 104000.00 217000.00 163921.51  21503.73 109000.00
# 36  021240          코웨이  48250.00 118091.42  88963.99  11627.03  66700.00
# 20  033780         KT&G  63600.00 137000.00 101453.70  12275.45  80200.00
# 17  000810         삼성화재 126000.00 328000.00 258808.89  40666.20 193000.00
# 64  005830       DB손해보험  23800.00  83800.00  60474.75  11079.18  44550.00
# 44  002380          KCC 107000.00 674778.55 383521.89 134745.58 207000.00
# 66  078930           GS  30300.00  76700.00  51157.74   9169.15  40300.00
# 3   015760         한국전력  16250.00  63000.00  37216.90  12264.39  23250.00
# 77  036460       한국가스공사  16600.00  64500.00  42141.58   8981.01  32250.00
# 23  002790         아모레G  43550.00 201272.01 108998.32  41665.59  63200.00
# 34  023530         롯데쇼핑  58300.00 357335.50 203523.08  71607.98 126500.00
# 56  012630          HDC   6880.00  99180.21  37150.26  24284.21  11050.00
# 35  035250         강원랜드  16250.00  45250.00  32630.14   6382.55  25900.00
# 46  001040           CJ  53100.00 323326.27 157748.08  61754.23  94700.00
# 31  010130         고려아연 293500.00 560000.00 448371.01  44930.57 403500.00
# 53  051600        한전KPS  24750.00 132000.00  52233.33  27018.66  28050.00
# 60  027410          BGF   2720.00  72211.92  24725.83  21007.83   6540.00
# 37  088350         한화생명    895.00   8550.00   5094.51   2226.16   3225.00
# 69  267250      현대중공업지주 165457.65 503073.72 340545.19  70851.48 281500.00
# 55  004800           효성  26482.52 293325.65 150851.00  80132.18  85600.00
# 41  001800       오리온홀딩스   6987.47 131057.44  43548.40  36478.84  14300.00
# 47  047810       한국항공우주  16350.00 103500.00  49555.93  19777.94  35850.00
# 62  007070        GS리테일  25950.00  66800.00  42578.17   8190.94  36950.00
# 12  032830         삼성생명  31900.00 137500.00  94028.00  22484.20  79400.00
# 74  271560          오리온  78500.00 158000.00 112831.65  17418.46 135000.00
#
#       7    8  C/M
# 81 1.50 0.01 0.66
# 36 1.33 0.03 0.75
# 20 1.27 0.04 0.79
# 17 1.34 0.05 0.75
# 64 1.36 0.08 0.74
# 44 1.85 0.10 0.54
# 66 1.27 0.12 0.79
# 3  1.60 0.13 0.62
# 77 1.31 0.14 0.77
# 23 1.72 0.14 0.58
# 34 1.61 0.14 0.62
# 56 3.36 0.14 0.30
# 35 1.26 0.15 0.79
# 46 1.67 0.15 0.60
# 31 1.11 0.16 0.90
# 53 1.86 0.19 0.54
# 60 3.78 0.19 0.26
# 37 1.58 0.20 0.63
# 69 1.21 0.20 0.83
# 55 1.76 0.21 0.57
# 41 3.05 0.21 0.33
# 47 1.38 0.24 0.72
# 62 1.15 0.25 0.87
# 12 1.18 0.26 0.84
# 52 1.45 0.26 0.69
# 11 1.09 0.27 0.91
# 32 1.10 0.27 0.91
# 57 1.20 0.28 0.83
# 14 1.22 0.29 0.82
# 51 1.07 0.30 0.93
# 54 1.27 0.31 0.79
# 33 1.05 0.32 0.95
# 61 1.07 0.34 0.94
# 73 1.10 0.39 0.91
# 30 1.08 0.39 0.93
# 9  1.06 0.39 0.94
# 78 1.05 0.40 0.95
# 38 1.05 0.41 0.95
# 68 1.05 0.41 0.95
# 40 1.05 0.43 0.95
# 10 1.01 0.46 0.99
# 18 1.02 0.47 0.98
# 45 1.01 0.49 0.99
# 42 0.99 0.52 1.01
# 65 0.99 0.54 1.02
# 39 0.96 0.56 1.04
# 26 0.97 0.57 1.03
# 21 0.97 0.59 1.03
# 58 0.94 0.61 1.07
# 71 0.91 0.65 1.10
# 79 0.75 0.71 1.33
# 50 0.90 0.76 1.11
# 16 0.86 0.77 1.17
# 6  0.94 0.78 1.07
# 28 0.84 0.80 1.19
# 49 0.79 0.83 1.27
# 7  0.81 0.85 1.23
# 85 0.85 0.87 1.17
# 27 0.81 0.88 1.23
# 74 0.84 0.90 1.20

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8910.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-15 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36300.0
# ChangeCode                        1
# Changes                       150.0
# ChagesRatio                     NaN
# Open                        36500.0
# High                        36550.0
# Low                         36100.0
# Volume                      48136.0
# Amount                 1747864300.0
# Marcap               229811960400.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            862
# ChangesRatio                   0.41
# Name: 11190491, dtype: object
