# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-15'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df1

# %%
wuryang = d[d['Market'] == 'KOSPI']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 931

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0           1         2         3         4        5         6    7  \
# 894  326030      SK바이오팜 104000.00 217000.00 163921.51 21503.73 109000.00 1.50
# 862  006345       대원전선우   1445.00   5110.00   3156.38   618.33   2635.00 1.20
# 520  044820    코스맥스비티아이   8720.00  26000.00  17739.59  3230.97  15150.00 1.17
# 116  181710         NHN  54900.00  95900.00  76124.39  7138.37  70500.00 1.08
# 740  010660        화천기계   1465.00   4170.00   2982.97   537.82   2565.00 1.16
# 320  003220        대원제약  10150.00  27000.00  18094.31  2714.93  16000.00 1.13
# 729  033250         체시스    825.00   2508.75   1830.66   331.45   1580.00 1.16
# 287  096760       JW홀딩스   3592.47   6233.42   5280.28   422.43   4965.00 1.06
# 111  051600       한전KPS  24750.00  32950.00  29244.72  1610.48  28050.00 1.04
# 142  330590        롯데리츠   4475.00   5920.00   5248.60   244.21   5070.00 1.04
# 514  007660      이수페타시스   1785.00   5750.00   3875.28   712.99   3355.00 1.16
# 302  122900     아이마켓코리아   6806.14  11827.41   9360.35   915.70   8700.00 1.08
# 846  008355       남선알미우  22250.00 104000.00  51831.30 18762.14  38600.00 1.34
# 661  044380        주연테크    772.12   1570.00   1164.43   145.29   1065.00 1.09
# 742  155900      바다로19호   2235.00   2640.00   2508.33   121.88   2425.00 1.03
# 903  339770      교촌에프앤비  17350.00  31000.00  19976.22  2772.40  18100.00 1.10
# 40   021240         코웨이  48250.00  88700.00  71469.31  7245.60  66700.00 1.07
# 209  001630      종근당홀딩스  86400.00 139000.00 114074.80 10045.25 107500.00 1.06
#
#        8  C/M
# 894 0.01 0.66
# 78  0.01 0.46
# 496 0.02 0.48
# 887 0.03 0.84
# 601 0.05 0.91
# 736 0.05 0.84
# 478 0.06 0.78
# 815 0.07 0.82
# 402 0.08 0.84
# 160 0.08 0.57
# 873 0.09 0.85
# 625 0.09 0.77
# 130 0.09 0.75
# 182 0.10 0.91
# 500 0.11 0.92
# 616 0.12 0.86
# 173 0.12 0.85
# 161 0.12 0.90
# 381 0.12 0.81
# 901 0.12 0.83
# 804 0.12 0.76
# 859 0.13 0.78
# 884 0.13 0.90
# 242 0.13 0.83
# 98  0.13 0.88
# 910 0.14 0.81
# 834 0.14 0.49
# 189 0.14 0.83
# 53  0.14 0.95
# 576 0.15 0.95
# 383 0.15 0.91
# 813 0.16 0.79
# 51  0.16 0.86
# 306 0.16 0.90
# 541 0.16 0.94
# 905 0.17 0.76
# 169 0.17 0.94
# 857 0.18 0.81
# 521 0.18 0.86
# 132 0.19 0.81
# 204 0.19 0.90
# 163 0.20 0.87
# 151 0.20 0.59
# 862 0.20 0.83
# 520 0.21 0.85
# 116 0.22 0.93
# 740 0.22 0.86
# 320 0.22 0.88
# 729 0.22 0.86
# 287 0.23 0.94
# 111 0.23 0.96
# 142 0.23 0.97
# 514 0.23 0.87
# 302 0.24 0.93
# 846 0.24 0.74
# 661 0.25 0.91
# 742 0.25 0.97
# 903 0.25 0.91
# 40  0.26 0.93
# 209 0.26 0.94

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8910.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-15 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36300.0
# ChangeCode                        1
# Changes                       150.0
# ChagesRatio                     NaN
# Open                        36500.0
# High                        36550.0
# Low                         36100.0
# Volume                      48136.0
# Amount                 1747864300.0
# Marcap               229811960400.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            862
# ChangesRatio                   0.41
# Name: 11190491, dtype: object
