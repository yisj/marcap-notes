# %%
# 우량주 분석
import datetime
# today=  datetime.datetime.now()
today = datetime.datetime.strptime('2021-11-05', '%Y-%m-%d')

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)
y7_ago = today - datetime.timedelta(days=7*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')
y7_ago = y7_ago.strftime('%Y-%m-%d')


y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-11-05'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\jae\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\jae\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3361: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]
df7 = df[df['Date']>y7_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df5

# %%
wuryang = d[d['Market'] == 'KOSPI']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 1004

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# C:\Users\jae\AppData\Local\Temp/ipykernel_19620/4028455208.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C', 'Cdf']
wdf = pd.DataFrame(data,columns=['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C', 'Cdf'] )
wdf['C/M'] = 1 / wdf['M/C']
wdf['Max/Current'] = wdf['Max']/wdf['Current']
wdf.sort_values(['Cdf'], ascending=[True]).to_csv('kospi-%s.csv' % today)
wdf.sort_values(['Cdf'], ascending=[True]).head(60)
# Out:
#        Code        Name       Min       Max      Mean      Std   Current  M/C  \
# 120  042670   현대두산인프라코어   6635.56  48895.83  21063.91  5836.70   8100.00 2.60
# 69   000210          DL  44947.61 201766.72 131935.51 31194.01  63900.00 2.06
# 537  000215         DL우  37000.00 127559.51  75559.81 17596.73  39900.00 1.89
# 191  170900       동아에스티  66197.81 126495.82  93372.03 10110.52  73200.00 1.28
# 165  001060      JW중외제약  18841.71  48031.54  34353.38  5862.26  22800.00 1.51
# 218  096760       JW홀딩스   3510.00   9889.76   6309.20  1299.18   3785.00 1.67
# 553  084670        동양고속  20750.00  36502.02  27780.13  3628.68  20750.00 1.34
# 906  950210  프레스티지바이오파마  22400.00  50000.00  30786.22  4466.02  22400.00 1.37
# 87   007310         오뚜기 426111.37 833773.38 635876.64 92391.96 472500.00 1.35
# 495  152550   한국ANKOR유전   1550.00   1980.00   1776.44   107.90   1590.00 1.12
# 926  381970         케이카  23000.00  25850.00  24500.00   782.91  23150.00 1.06
# 912  383800       LX홀딩스   8710.00  12250.00  10204.59   851.97   8810.00 1.16
# 613  027740         마니커   1811.41   6247.96   3005.46   739.40   1815.00 1.66
# 819  143210     핸즈코퍼레이션   4900.00  11650.00   7573.65  1368.50   5540.00 1.37
# 909  361610  SK아이이테크놀로지 138000.00 235500.00 189311.48 30075.68 145500.00 1.30
# 911  380440   엔에이치스팩19호   2085.00   2470.00   2186.78    60.71   2100.00 1.04
# 222  006060        화승인더   5660.00  13400.00   8771.36  1572.86   6540.00 1.34
# 243  214420        토니모리   6045.13  25172.05  12858.35  4553.27   6580.00 1.95
# 184  006840       AK홀딩스  12000.00  86900.00  46387.39 20118.32  25450.00 1.82
# 883  322000    현대에너지솔루션  13000.00  43850.00  29049.38  7271.10  21600.00 1.34
# 24   011170       롯데케미칼 117000.00 474500.00 293034.99 71867.58 219500.00 1.34
# 50   000120      CJ대한통운 118500.00 203000.00 160207.08 15388.14 144500.00 1.11
# 135  114090         GKL  10900.00  34000.00  20470.26  4715.24  15700.00 1.30
# 276  008060          대덕   4833.88  29117.26  14044.51  6400.61   7670.00 1.83
# 233  024720     한국콜마홀딩스  13181.39  52473.64  29415.11  7253.63  22200.00 1.33
# 33   023530        롯데쇼핑  58300.00 357335.50 171807.01 69320.81 103000.00 1.67
#
#      Cdf  C/M  Max/Current
# 120 0.01 0.38         6.04
# 69  0.01 0.48         3.16
# 537 0.02 0.53         3.20
# 191 0.02 0.78         1.73
# 165 0.02 0.66         2.11
# 218 0.03 0.60         2.61
# 553 0.03 0.75         1.76
# 906 0.03 0.73         2.23
# 87  0.04 0.74         1.76
# 495 0.04 0.90         1.25
# 926 0.04 0.94         1.12
# 912 0.05 0.86         1.39
# 613 0.05 0.60         3.44
# 819 0.07 0.73         2.10
# 909 0.07 0.77         1.62
# 911 0.08 0.96         1.18
# 222 0.08 0.75         2.05
# 243 0.08 0.51         3.83
# 890 0.09 0.71         2.20
# 372 0.09 0.75         2.04
# 133 0.10 0.72         2.13
# 197 0.10 0.67         2.12
# 112 0.10 0.74         1.95
# 916 0.10 0.82         1.61
# 270 0.11 0.55         3.93
# 913 0.11 0.79         2.07
# 114 0.11 0.68         2.72
# 584 0.11 0.80         1.74
# 918 0.11 0.94         1.13
# 923 0.11 0.88         1.39
# 767 0.11 0.81         2.09
# 299 0.11 0.68         2.50
# 256 0.11 0.48         3.82
# 188 0.11 0.64         3.11
# 660 0.12 0.71         2.51
# 427 0.12 0.54         4.31
# 861 0.12 0.91         1.52
# 526 0.12 0.86         1.82
# 314 0.12 0.77         1.97
# 150 0.12 0.57         2.97
# 63  0.13 0.91         1.29
# 356 0.13 0.75         2.28
# 20  0.13 0.56         3.21
# 623 0.13 0.72         1.99
# 502 0.13 0.68         2.44
# 324 0.13 0.72         2.16
# 209 0.13 0.89         1.42
# 919 0.14 0.81         1.72
# 21  0.14 0.83         1.68
# 655 0.14 0.30        11.43
# 897 0.14 0.87         2.00
# 899 0.15 0.90         1.75
# 184 0.15 0.55         3.41
# 883 0.15 0.74         2.03
# 24  0.15 0.75         2.16
# 50  0.15 0.90         1.40
# 135 0.16 0.77         2.17
# 276 0.16 0.55         3.80
# 233 0.16 0.75         2.36
# 33  0.16 0.60         3.47

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']

# %%
df[df['Code'] == '054950'].iloc[-1]
