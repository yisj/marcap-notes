# %%
import pandas as pd
df = pd.read_csv('data/marcap-2020.csv.gz', dtype={"Code": str}, parse_dates=['Date'])

# %%
df.head(10)
# Out:
#      Code      Name Market Dept     Close  ChangeCode  Changes  ChagesRatio  \
# 0  005930      삼성전자  KOSPI  NaN   55200.0           2   -600.0        -1.08
# 1  000660    SK하이닉스  KOSPI  NaN   94700.0           1    600.0         0.64
# 2  005935     삼성전자우  KOSPI  NaN   45600.0           1    200.0         0.44
# 3  035420     NAVER  KOSPI  NaN  182500.0           2  -4000.0        -2.14
# 4  207940  삼성바이오로직스  KOSPI  NaN  428500.0           2  -4500.0        -1.04
# 5  005380       현대차  KOSPI  NaN  118000.0           2  -2500.0        -2.07
# 6  012330     현대모비스  KOSPI  NaN  247500.0           2  -8500.0        -3.32
# 7  068270      셀트리온  KOSPI  NaN  180000.0           2  -1000.0        -0.55
# 8  051910      LG화학  KOSPI  NaN  314000.0           2  -3500.0        -1.10
# 9  005490     POSCO  KOSPI  NaN  236000.0           2   -500.0        -0.21
#
#        Open      High       Low      Volume        Amount        Marcap  \
# ...

# %%
df = pd.read_csv("data/marcap-2021.csv.gz")

# %%
df.head(10)
# Out:
#      Code      Name Market Dept     Close  ChangeCode  Changes  ChagesRatio  \
# 0  005930      삼성전자  KOSPI  NaN   83000.0           1   2000.0         2.47
# 1  000660    SK하이닉스  KOSPI  NaN  126000.0           1   7500.0         6.33
# 2  051910      LG화학  KOSPI  NaN  889000.0           1  65000.0         7.89
# 3  005935     삼성전자우  KOSPI  NaN   74400.0           1    800.0         1.09
# 4  207940  삼성바이오로직스  KOSPI  NaN  829000.0           1   3000.0         0.36
# 5  035420     NAVER  KOSPI  NaN  293000.0           1    500.0         0.17
# 6  068270      셀트리온  KOSPI  NaN  347500.0           2 -11500.0        -3.20
# 7  006400     삼성SDI  KOSPI  NaN  671000.0           1  43000.0         6.85
# 8  005380       현대차  KOSPI  NaN  207500.0           1  15500.0         8.07
# 9  035720       카카오  KOSPI  NaN  396000.0           1   6500.0         1.67
#
#        Open      High       Low      Volume        Amount        Marcap  \
# ...

# %%
df
# Out:
#          Code      Name Market   Dept     Close  ChangeCode  Changes  \
# 0      005930      삼성전자  KOSPI    NaN   83000.0           1   2000.0
# 1      000660    SK하이닉스  KOSPI    NaN  126000.0           1   7500.0
# 2      051910      LG화학  KOSPI    NaN  889000.0           1  65000.0
# 3      005935     삼성전자우  KOSPI    NaN   74400.0           1    800.0
# 4      207940  삼성바이오로직스  KOSPI    NaN  829000.0           1   3000.0
# ...       ...       ...    ...    ...       ...         ...      ...
# 33878  238500      로보쓰리  KONEX  일반기업부     585.0           2     -8.0
# 33879  001529     동양3우B  KOSPI    NaN   29500.0           2   -400.0
# 33880  224020   에스케이씨에스  KONEX  일반기업부     799.0           1     99.0
# 33881  242350   피엔아이컴퍼니  KONEX  일반기업부     459.0           1      2.0
# 33882  225860   엠앤씨생명과학  KONEX  일반기업부      85.0           2     -1.0
#
#        ChagesRatio      Open      High       Low      Volume        Amount  \
# ...

# %%
df.iloc[0]
# Out:
# Code                      005930
# Name                        삼성전자
# Market                     KOSPI
# Dept                         NaN
# Close                    83000.0
# ChangeCode                     1
# Changes                   2000.0
# ChagesRatio                 2.47
# Open                     81000.0
# High                     84400.0
# Low                      80200.0
# Volume                38655276.0
# Amount           3185356823460.0
# Marcap         495491951650000.0
# Stocks                5969782550
# MarketId                     STK
# Rank                           1
# Date                  2021-01-04
# Name: 0, dtype: object

# %%
df.iloc[0]["Code"]
# Out:
# '005930'

# %%
df.iloc[0]["Date"]
# Out:
# '2021-01-04'

# %%
df["Code"].dtype
# Out:
# dtype('O')

# %%
df["Date"].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#          Code      Name Market   Dept     Close  ChangeCode  Changes  \
# 0      005930      삼성전자  KOSPI    NaN   83000.0           1   2000.0
# 1      000660    SK하이닉스  KOSPI    NaN  126000.0           1   7500.0
# 2      051910      LG화학  KOSPI    NaN  889000.0           1  65000.0
# 3      005935     삼성전자우  KOSPI    NaN   74400.0           1    800.0
# 4      207940  삼성바이오로직스  KOSPI    NaN  829000.0           1   3000.0
# ...       ...       ...    ...    ...       ...         ...      ...
# 33878  238500      로보쓰리  KONEX  일반기업부     585.0           2     -8.0
# 33879  001529     동양3우B  KOSPI    NaN   29500.0           2   -400.0
# 33880  224020   에스케이씨에스  KONEX  일반기업부     799.0           1     99.0
# 33881  242350   피엔아이컴퍼니  KONEX  일반기업부     459.0           1      2.0
# 33882  225860   엠앤씨생명과학  KONEX  일반기업부      85.0           2     -1.0
#
#        ChagesRatio      Open      High       Low      Volume        Amount  \
# ...

# %%
df.dtypes
# Out:
# Code            object
# Name            object
# Market          object
# Dept            object
# Close          float64
# ChangeCode       int64
# Changes        float64
# ChagesRatio    float64
# Open           float64
# High           float64
# Low            float64
# Volume         float64
# Amount         float64
# Marcap         float64
# Stocks           int64
# MarketId        object
# Rank             int64
# Date            object
# dtype: object

# %%
df = pd.read_csv("data/marcap-2021.csv.gz", dtype={"Code": str}, parse_dates=["Date"])

# %%
df.dtypes
# Out:
# Code                   object
# Name                   object
# Market                 object
# Dept                   object
# Close                 float64
# ChangeCode              int64
# Changes               float64
# ChagesRatio           float64
# Open                  float64
# High                  float64
# Low                   float64
# Volume                float64
# Amount                float64
# Marcap                float64
# Stocks                  int64
# MarketId               object
# Rank                    int64
# Date           datetime64[ns]
# dtype: object

# %%
df["Code"].dtype
# Out:
# dtype('O')

# %%
df["Date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df[2000:2010]
# Out:
#         Code     Name  Market             Dept    Close  ChangeCode  Changes  \
# 2000  039310       세중  KOSDAQ            중견기업부   2835.0           1     80.0
# 2001  067920  이글루시큐리티  KOSDAQ            벤처기업부   4670.0           2   -100.0
# 2002  010770    평화홀딩스   KOSPI              NaN   3510.0           2    -20.0
# 2003  003680     한성기업   KOSPI              NaN   8250.0           2    -60.0
# 2004  046070      코다코  KOSDAQ  투자주의환기종목(소속부없음)   1310.0           1     20.0
# 2005  046310    백금T&A  KOSDAQ            중견기업부   3115.0           1     85.0
# 2006  009140     경인전자   KOSPI              NaN  32550.0           4   7500.0
# 2007  317830  에스피시스템스  KOSDAQ            벤처기업부   6250.0           1     50.0
# 2008  007120   미래아이앤지   KOSPI              NaN    393.0           2     -1.0
# 2009  213090  미래테크놀로지  KOSDAQ            중견기업부   8310.0           1     80.0
#
#       ChagesRatio     Open     High      Low     Volume        Amount  \
# ...

# %%
df[df["Changes"] == 0.0]
# Out:
#          Code       Name  Market         Dept     Close  ChangeCode  Changes  \
# 75     139480        이마트   KOSPI          NaN  151500.0           3      0.0
# 77     088980     맥쿼리인프라   KOSPI          NaN   10650.0           3      0.0
# 87     293490     카카오게임즈  KOSDAQ        중견기업부   46000.0           3      0.0
# 113    001040         CJ   KOSPI          NaN   92100.0           3      0.0
# 160    047050   포스코인터내셔널   KOSPI          NaN   14550.0           3      0.0
# ...       ...        ...     ...          ...       ...         ...      ...
# 33832  323280     신영스팩5호  KOSDAQ  SPAC(소속부없음)    2115.0           3      0.0
# 33846  347140  케이프이에스제4호  KOSDAQ  SPAC(소속부없음)    2060.0           3      0.0
# 33849  308700        테크엔   KONEX        일반기업부    1500.0           3      0.0
# 33862  014915      성문전자우   KOSPI          NaN    8200.0           3      0.0
# 33870  001527      동양2우B   KOSPI          NaN   11650.0           3      0.0
#
# ...
