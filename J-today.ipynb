# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'

y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-16'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
d = df4

# %%
wuryang = d[d['Dept'] == '중견기업부']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 867

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-11-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0           1        2         3        4        5        6    7  \
# 664  038340         UCI   678.23   4251.70  2726.72   813.91   806.00 3.38
# 104  138690       엘아이에스  4525.00  15438.67 10587.91  2335.00  5360.00 1.98
# 690  101400        엔시트론   628.86   3494.95  1770.58   532.30   801.00 2.21
# 176  044180          KD   811.00   5958.70  2792.12   950.43  1165.00 2.40
# 293  017250         인터엠  1350.00   4295.00  2538.59   611.52  1510.00 1.68
# 752  332570         와이팜 10050.00  18800.00 13882.57  1732.14 11000.00 1.26
# 145  030350      드래곤플라이  1038.70   7336.63  3590.34  1074.95  2460.00 1.46
# 769  129890          앱코 25100.00  33800.00 28339.86  1993.44 26250.00 1.08
# 18   067080        대화제약  5815.03  33431.52 18512.13  5825.10 12450.00 1.49
# 778  348030        모비릭스 20850.00  36302.19 25081.04  4020.08 20900.00 1.20
# 741  108860       셀바스AI  2360.00   7280.00  4180.14  1119.70  3035.00 1.38
# 546  023160          태광  5670.00  15200.00 10082.73  2238.30  7800.00 1.29
# 196  050120      라이브플렉스  2768.77  11200.06  5642.04  1136.48  4505.00 1.25
# 717  217480     에스디생명공학  2360.00  22098.79  9151.41  4262.02  5020.00 1.82
# 522  066360        체리부로  1140.00   4575.00  2724.53   527.70  2220.00 1.23
# 226  161570  THE MIDONG  1137.31   8222.24  3429.23  1701.60  1810.00 1.89
# 459  047770      코데즈컴바인  1315.00   4145.00  2897.10   442.24  2485.00 1.17
# 85   036000         예림당  1485.00  15300.00  6116.73  3232.53  3105.00 1.97
# 36   222040     코스맥스엔비티  2860.00  29350.00 14445.32  7059.21  8040.00 1.80
#
#        8  C/M
# 664 0.01 0.30
# 104 0.01 0.51
# 690 0.03 0.45
# 176 0.04 0.42
# 293 0.05 0.59
# 752 0.05 0.79
# 691 0.06 0.66
# 63  0.07 0.63
# 401 0.07 0.80
# 90  0.07 0.69
# 750 0.07 0.84
# 559 0.08 0.38
# 567 0.08 0.39
# 141 0.08 0.63
# 742 0.08 0.78
# 464 0.08 0.67
# 160 0.08 0.50
# 771 0.08 0.84
# 496 0.08 0.68
# 40  0.09 0.64
# 565 0.09 0.76
# 710 0.10 0.76
# 685 0.11 0.62
# 407 0.11 0.67
# 547 0.11 0.75
# 53  0.11 0.58
# 286 0.11 0.54
# 549 0.11 0.58
# 726 0.12 0.59
# 444 0.12 0.33
# 634 0.12 0.34
# 681 0.12 0.85
# 432 0.12 0.81
# 150 0.12 0.73
# 45  0.12 0.24
# 447 0.12 0.66
# 503 0.12 0.37
# 336 0.12 0.45
# 736 0.13 0.60
# 177 0.13 0.63
# 639 0.13 0.59
# 76  0.14 0.74
# 767 0.14 0.89
# 554 0.14 0.57
# 14  0.14 0.43
# 730 0.15 0.64
# 165 0.15 0.71
# 145 0.15 0.69
# 769 0.15 0.93
# 18  0.15 0.67
# 778 0.15 0.83
# 741 0.15 0.73
# 546 0.15 0.77
# 196 0.16 0.80
# 717 0.17 0.55
# 522 0.17 0.81
# 226 0.17 0.53
# 459 0.18 0.86
# 85  0.18 0.51
# 36  0.18 0.56

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8880.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12900.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-16 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36200.0
# ChangeCode                        2
# Changes                      -100.0
# ChagesRatio                     NaN
# Open                        36650.0
# High                        36650.0
# Low                         36150.0
# Volume                      35764.0
# Amount                 1298677900.0
# Marcap               229178869600.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            872
# ChangesRatio                  -0.28
# Name: 11192942, dtype: object

# %%
wdf[wdf[1]=="파루"]
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5, 6, 7, 8, C/M]
# Index: []
