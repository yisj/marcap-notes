# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)

y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')

y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-17'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df5

# %%
wuryang = d[d['Market'] == 'KOSPI']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 990

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C', 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf['Max/Current'] = wdf[3]/wdf[6]
wdf.sort_values([8], ascending=[True]).to_csv('kospi-%s.csv' % today)
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0          1         2          3         4         5         6  \
# 77   000210         DL  61000.00  273824.77 190869.24  28080.33  78000.00
# 525  000215        DL우  37000.00  127559.51  78170.74  14089.06  39850.00
# 894  326030     SK바이오팜 104000.00  217000.00 163310.34  22121.93 111500.00
# 641  096300     베트남개발1    227.00     642.54    393.98     81.86    229.00
# 574  004450       삼화왕관  32100.00   55100.00  45532.59   4223.48  37750.00
# 736  153360     하이골드3호   1170.00    2890.00   1695.55    246.94   1245.00
# 540  019685       대교우B   2175.00    5690.00   4375.24    994.39   2595.00
# 356  000155        두산우  25800.00   92604.19  69672.91  17988.37  38600.00
# 36   021240        코웨이  48250.00  118091.42  87695.80  12160.57  66800.00
# 391  168490      한국패러랠   1890.00    2665.00   2344.54    237.24   1955.00
# 68   012750        에스원  73800.00  115000.00  94058.56   6869.98  82900.00
# 225  003920       남양유업 255000.00  944000.00 578928.63 174057.96 297500.00
# 17   033780       KT&G  63600.00  137000.00 101068.68  13022.01  80100.00
# 498  034590     인천도시가스  20950.00   32050.00  28932.34   2266.60  25350.00
# 20   000810       삼성화재 126000.00  309000.00 251919.66  40622.39 188000.00
# 182  019680         대교   3075.00   11000.00   6827.47   1720.75   4135.00
# 115  000150         두산  26050.00  177326.56 107927.24  38979.88  48800.00
# 409  007980      태평양물산   1129.89    4659.29   2947.50    677.65   1940.00
# 381  015360     예스코홀딩스  26300.00   44700.00  38097.68   2810.29  33950.00
# 663  000157      두산2우B  25800.00  108500.00  75376.77  12379.19  57200.00
# 470  152550  한국ANKOR유전   1560.00    2110.00   1829.33    115.89   1660.00
# 215  002960      한국쉘석유 206000.00  501000.00 349609.30  69745.06 248000.00
# 352  004970       신라교역   6850.00   17800.00  13477.81   2372.69  10050.00
# 390  025560       미래산업   2494.02   14331.46   7069.20   2603.27   3315.00
# 499  000850       화천기공  23950.00   62900.00  45280.18   9268.31  31950.00
# 575  084670       동양고속  20856.51   36502.02  28951.05   3504.78  23950.00
# 540 1.69 0.04 0.59         2.19
# 356 1.80 0.04 0.55         2.40
# 36  1.31 0.04 0.76         1.77
# 391 1.20 0.05 0.83         1.36
# 68  1.13 0.05 0.88         1.39
# 225 1.95 0.05 0.51         3.17
# 17  1.26 0.05 0.79         1.71
# 498 1.14 0.06 0.88         1.26
# 20  1.34 0.06 0.75         1.64
# 182 1.65 0.06 0.61         2.66
# 115 2.21 0.06 0.45         3.63
# 409 1.52 0.07 0.66         2.40
# 381 1.12 0.07 0.89         1.32
# 663 1.32 0.07 0.76         1.90
# 470 1.10 0.07 0.91         1.27
# 215 1.41 0.07 0.71         2.02
# 352 1.34 0.07 0.75         1.77
# 390 2.13 0.07 0.47         4.32
# 499 1.42 0.08 0.71         1.97
# 575 1.21 0.08 0.83         1.52
# 186 1.54 0.08 0.65         2.29
# 274 1.32 0.08 0.76         1.77
# 725 1.13 0.08 0.88         1.48
# 734 1.19 0.08 0.84         1.59
# 48  1.36 0.08 0.73         1.88
# 305 1.19 0.08 0.84         1.66
# 377 1.32 0.09 0.76         2.07
# 277 1.57 0.09 0.64         2.75
# 750 1.39 0.10 0.72         2.07
# 219 1.20 0.10 0.84         1.44
# 461 1.38 0.10 0.72         2.07
# 480 1.38 0.10 0.72         2.00
# 396 1.44 0.10 0.69         2.98
# 176 1.29 0.10 0.77         1.76
# 268 2.13 0.10 0.47         4.27
# 329 1.59 0.10 0.63         2.86
# 273 1.37 0.10 0.73         1.87
# 477 1.25 0.11 0.80         1.98
# 180 1.63 0.11 0.61         2.97
# 580 1.67 0.11 0.60         3.02
# 295 1.52 0.11 0.66         2.50
# 793 1.14 0.11 0.88         1.44
# 188 1.48 0.11 0.68         2.19
# 241 1.52 0.11 0.66         2.43
# 57  1.71 0.11 0.58         2.58
# 600 1.26 0.11 0.79         1.97
# 496 1.56 0.12 0.64         3.23
# 901 1.21 0.12 0.83         2.08
# 296 1.35 0.12 0.74         2.36
# 50  1.29 0.12 0.78         1.91
# 75  1.37 0.12 0.73         2.05
# 285 1.96 0.12 0.51         4.59
# 720 1.50 0.12 0.67         2.24
# 145 1.67 0.12 0.60         3.02

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8930.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12650.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-17 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36500.0
# ChangeCode                        1
# Changes                       300.0
# ChagesRatio                     NaN
# Open                        36550.0
# High                        36650.0
# Low                         36000.0
# Volume                      30184.0
# Amount                 1097527900.0
# Marcap               231078142000.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            873
# ChangesRatio                   0.83
# Name: 11195385, dtype: object
