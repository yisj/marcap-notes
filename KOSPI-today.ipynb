# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)

y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')

y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-15'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df6

# %%
wuryang = d[d['Market'] == 'KOSPI']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 1011

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0          1         2          3         4         5         6  \
# 91   000210         DL  61000.00  273824.77 187022.48  27615.80  78300.00
# 894  326030     SK바이오팜 104000.00  217000.00 163921.51  21503.73 109000.00
# 521  000215        DL우  37000.00  127559.51  75406.30  14432.52  40300.00
# 601  096300     베트남개발1    227.00     642.54    403.99     78.94    228.00
# 549  019685       대교우B   2175.00    6000.00   4516.48    972.61   2580.00
# 36   021240        코웨이  48250.00  118091.42  88963.99  11627.03  66700.00
# 611  153360     하이골드3호   1170.00    3690.00   1841.03    452.26   1270.00
# 380  013520    화승코퍼레이션   1483.39    6462.41   3543.13   1087.00   2175.00
# 632  172580    하이골드12호   1920.00    3930.00   2549.29    398.43   2055.00
# 303  005810      풍산홀딩스  15543.09   45236.78  30726.61   6490.52  22750.00
# 163  093050         LF   8940.00   36900.00  23677.45   6309.02  15950.00
# 352  002360    SH에너지화학    507.00    2310.00   1322.75    325.36    926.00
# 92   001450       현대해상  17700.00   49200.00  32446.44   7183.68  23750.00
# 160  002270       롯데푸드 211500.00 1438556.90 704103.95 269438.18 378000.00
# 760  000325     노루홀딩스우  10000.00   29200.00  18235.33   2022.52  15800.00
# 396  152550  한국ANKOR유전   1560.00    2640.00   1895.91    196.87   1660.00
#
#        7    8  C/M
# 91  2.39 0.00 0.42
# 894 1.50 0.01 0.66
# 521 1.87 0.01 0.53
# 601 1.77 0.01 0.56
# 549 1.75 0.02 0.57
# 36  1.33 0.03 0.75
# 311 1.81 0.03 0.55
# 567 1.20 0.03 0.83
# 350 1.21 0.03 0.83
# 222 2.07 0.03 0.48
# 209 1.76 0.04 0.57
# 20  1.27 0.04 0.79
# 81  2.28 0.05 0.44
# 237 1.41 0.05 0.71
# 17  1.34 0.05 0.75
# 517 1.26 0.05 0.79
# 320 1.63 0.05 0.61
# 200 1.59 0.05 0.63
# 74  1.14 0.05 0.87
# 358 1.13 0.06 0.89
# 208 1.51 0.06 0.66
# 444 1.18 0.06 0.85
# 323 1.40 0.07 0.72
# 441 1.45 0.07 0.69
# 554 2.29 0.07 0.44
# 495 1.43 0.07 0.70
# 430 1.52 0.07 0.66
# 252 1.59 0.07 0.63
# 235 1.44 0.07 0.70
# 698 1.64 0.08 0.61
# 600 1.30 0.08 0.77
# 67  1.36 0.08 0.74
# 297 1.23 0.08 0.81
# 193 1.61 0.08 0.62
# 174 1.83 0.08 0.55
# 265 1.43 0.08 0.70
# 728 1.38 0.08 0.73
# 366 1.56 0.09 0.64
# 229 1.20 0.09 0.83
# 449 1.45 0.09 0.69
# 782 1.64 0.09 0.61
# 118 1.37 0.09 0.73
# 175 1.60 0.09 0.62
# 44  1.85 0.10 0.54
# 457 1.17 0.10 0.85
# 675 1.56 0.10 0.64
# 228 2.06 0.10 0.49
# 256 2.31 0.10 0.43
# 433 2.71 0.10 0.37
# 298 1.29 0.10 0.77
# 611 1.45 0.10 0.69
# 380 1.63 0.10 0.61
# 632 1.24 0.11 0.81
# 303 1.35 0.11 0.74
# 163 1.48 0.11 0.67
# 352 1.43 0.11 0.70
# 92  1.37 0.11 0.73
# 160 1.86 0.11 0.54
# 760 1.15 0.11 0.87
# 396 1.14 0.12 0.88

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8910.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-15 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36300.0
# ChangeCode                        1
# Changes                       150.0
# ChagesRatio                     NaN
# Open                        36500.0
# High                        36550.0
# Low                         36100.0
# Volume                      48136.0
# Amount                 1747864300.0
# Marcap               229811960400.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            862
# ChangesRatio                   0.41
# Name: 11190491, dtype: object
