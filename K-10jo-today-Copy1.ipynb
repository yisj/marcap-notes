# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)

y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')

y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-15'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df6

# %%
w = d[d['Market'] == 'KOSPI']
wuryang = w[w['Marcap'] > 10000000000000]

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 49

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#          0         1         2          3          4         5          6  \
# 42  326030    SK바이오팜 104000.00  217000.00  163921.51  21503.73  109000.00
# 20  033780      KT&G  63600.00  137000.00  101453.70  12275.45   80200.00
# 17  000810      삼성화재 126000.00  328000.00  258808.89  40666.20  193000.00
# 3   015760      한국전력  16250.00   63000.00   37216.90  12264.39   23250.00
# 23  002790      아모레G  43550.00  201272.01  108998.32  41665.59   63200.00
# 36  023530      롯데쇼핑  58300.00  357335.50  203523.08  71607.98  126500.00
# 27  010130      고려아연 293500.00  560000.00  448371.01  44930.57  403500.00
# 30  047810    한국항공우주  16350.00  103500.00   49555.93  19777.94   35850.00
# 12  032830      삼성생명  31900.00  137500.00   94028.00  22484.20   79400.00
# 11  055550      신한지주  20731.73   50853.04   38475.77   5360.25   35150.00
# 14  090430    아모레퍼시픽 120500.00  445000.00  275676.62  90194.35  226500.00
# 29  008930    한미사이언스  19174.29  155486.39   75015.09  31215.87   59300.00
# 9   018260   삼성에스디에스 125000.00  335000.00  199301.43  40822.72  188000.00
# 41  316140    우리금융지주   6560.00   15067.31   10609.73   1927.10   10100.00
# 31  010950     S-Oil  48500.00  137500.00   88841.75  20492.48   84400.00
# 35  251270       넷마블  84429.27  197499.82  126366.26  27248.33  120500.00
# 10  028260      삼성물산  75617.36  171534.69  124277.81  18541.86  122500.00
# 18  034220   LG디스플레이   8900.00   38900.00   22720.20   6688.22   22200.00
# 28  011170     롯데케미칼 117000.00  474500.00  289840.12  67544.76  300500.00
# 24  009540    한국조선해양  66300.00  192756.81  118423.71  21840.84  122000.00
# 21  034730        SK 107000.00  355000.00  242760.81  37884.41  251000.00
# 16  105560      KB금융  26050.00   68980.05   43912.09   9832.29   51200.00
# 6   017670     SK텔레콤 165500.00  293500.00  240798.03  21236.04  257000.00
# 32  086790    하나금융지주  18450.00   54716.42   34730.77   7983.11   41500.00
# 7   005490     POSCO 138000.00  395000.00  250552.95  54535.45  308000.00
# 39  068270      셀트리온  49704.03  403410.57  166995.36  86066.30  289000.00
# 33  207940  삼성바이오로직스 142000.00  880000.00  430836.68 190875.95  735000.00
# 25  096770   SK이노베이션  57300.00  317500.00  162215.82  38589.57  228500.00
# 19  051900    LG생활건강 690000.00 1680000.00 1135145.96 234164.00 1580000.00
# 22  003550        LG  46250.00  115500.00   72336.01   9933.53   91600.00
# 5   012330     현대모비스 129356.00  361996.25  241624.76  30277.88  302000.00
# 43  019170      신풍제약   3362.44  198000.00   19411.69  35914.73   95000.00
# 37  036570     엔씨소프트 168807.55 1038000.00  441771.06 211969.30  930000.00
# 40  009150      삼성전기  45350.00  217000.00   97969.35  37533.09  191000.00
# 2   000660    SK하이닉스  25750.00  148500.00   66395.32  25047.72  136500.00
# 0   005930      삼성전자  26327.32   91000.00   47008.38  12195.20   81800.00
# 45  018880     한온시스템   6600.00   18850.00   10972.93   2091.49   17200.00
# 1   005380       현대차  65900.00  267500.00  145601.35  27923.60  232000.00
# 4   005935     삼성전자우  22781.07   81000.00   39997.63  10544.72   73100.00
# 34  006400     삼성SDI  76800.00  805000.00  222136.80 138918.27  686000.00
# 38  035720       카카오  54276.10  513797.46  134243.45 100612.56  479000.00
# 26  066570      LG전자  39800.00  185000.00   72164.12  22733.08  151500.00
# 8   035420     NAVER  92609.05  399500.00  167848.84  59183.63  383000.00
# 15  051910      LG화학 199961.41 1028000.00  367034.27 160163.94  966000.00
# 13  000270       기아차  21500.00  101500.00   41599.69  10540.07   85800.00
# 44  003670    포스코케미칼   7335.78  173500.00   32933.00  26877.53  157500.00
#
#       7    8  C/M
# 42 1.50 0.01 0.66
# 20 1.27 0.04 0.79
# 17 1.34 0.05 0.75
# 3  1.60 0.13 0.62
# 23 1.72 0.14 0.58
# 36 1.61 0.14 0.62
# 27 1.11 0.16 0.90
# 30 1.38 0.24 0.72
# 12 1.18 0.26 0.84
# 11 1.09 0.27 0.91
# 14 1.22 0.29 0.82
# 29 1.27 0.31 0.79
# 9  1.06 0.39 0.94
# 41 1.05 0.40 0.95
# 31 1.05 0.41 0.95
# 35 1.05 0.41 0.95
# 10 1.01 0.46 0.99
# 18 1.02 0.47 0.98
# 28 0.96 0.56 1.04
# 24 0.97 0.57 1.03
# 21 0.97 0.59 1.03
# 16 0.86 0.77 1.17
# 6  0.94 0.78 1.07
# 32 0.84 0.80 1.19
# 7  0.81 0.85 1.23
# 39 0.58 0.92 1.73
# 33 0.59 0.94 1.71
# 25 0.71 0.96 1.41
# 19 0.72 0.97 1.39
# 22 0.79 0.97 1.27
# 5  0.80 0.98 1.25
# 43 0.20 0.98 4.89
# 37 0.48 0.99 2.11
# 40 0.51 0.99 1.95
# 2  0.49 1.00 2.06
# 0  0.57 1.00 1.74
# 45 0.64 1.00 1.57
# 1  0.63 1.00 1.59
# 4  0.55 1.00 1.83
# 34 0.32 1.00 3.09
# 38 0.28 1.00 3.57
# 26 0.48 1.00 2.10
# 8  0.44 1.00 2.28
# 15 0.38 1.00 2.63
# 13 0.48 1.00 2.06
# 44 0.21 1.00 4.78

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8910.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-15 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36300.0
# ChangeCode                        1
# Changes                       150.0
# ChagesRatio                     NaN
# Open                        36500.0
# High                        36550.0
# Low                         36100.0
# Volume                      48136.0
# Amount                 1747864300.0
# Marcap               229811960400.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            862
# ChangesRatio                   0.41
# Name: 11190491, dtype: object
