# %%
# 우량주 분석
import datetime
# today=  datetime.datetime.now()
today = datetime.datetime.strptime('2021-03-29', '%Y-%m-%d')

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)
y7_ago = today - datetime.timedelta(days=7*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')
y7_ago = y7_ago.strftime('%Y-%m-%d')


y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-29'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]
df7 = df[df['Date']>y7_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df5

# %%
wuryang = d[d['Market'] == 'KOSPI']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 991

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C', 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf['Max/Current'] = wdf[3]/wdf[6]
wdf.sort_values([8], ascending=[True]).to_csv('kospi-%s.csv' % today)
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0          1         2         3         4         5         6    7  \
# 70   000210         DL  61000.00 273824.77 190123.24  29320.21  89000.00 2.14
# 893  326030     SK바이오팜 101000.00 217000.00 160766.48  24689.38 101000.00 1.59
# 522  000215        DL우  37000.00 127559.51  78000.47  14361.27  43500.00 1.79
# 650  096300     베트남개발1    227.00    642.54    392.52     82.78    230.00 1.71
# 34   021240        코웨이  48250.00 118091.42  87470.41  12253.94  64900.00 1.35
# 578  004450       삼화왕관  32100.00  55100.00  45506.85   4258.59  37900.00 1.20
# 535  019685       대교우B   2175.00   5690.00   4356.48    999.67   2610.00 1.67
# 67   012750        에스원  73800.00 115000.00  94006.61   6930.25  82300.00 1.14
# 354  000155        두산우  25800.00  92604.19  69517.34  18150.87  39400.00 1.76
# 402  007980      태평양물산   1129.89   4659.29   2933.53    677.57   1840.00 1.59
# 390  015360     예스코홀딩스  26300.00  44700.00  38077.32   2829.63  33550.00 1.13
# 17   033780       KT&G  63600.00 137000.00 100888.01  13108.29  80200.00 1.26
# 397  168490      한국패러랠   1890.00   2665.00   2340.38    238.40   1965.00 1.19
# 19   000810       삼성화재 126000.00 309000.00 251202.28  40794.65 187000.00 1.34
# 225  003920       남양유업 255000.00 944000.00 575616.23 174517.34 301000.00 1.91
# 327  013520    화승코퍼레이션   1483.39   5888.40   3252.60    947.63   1790.00 1.82
# 182  019680         대교   3075.00  11000.00   6786.82   1710.58   4190.00 1.62
# 734  153360     하이골드3호   1170.00   2890.00   1693.04    249.00   1320.00 1.28
# 380  025560       미래산업   2494.02  14331.46   7011.32   2589.34   3150.00 2.23
# 407  091090      세원셀론텍   1282.00   5816.32   2807.91    677.03   1815.00 1.55
# 249  096760      JW홀딩스   3592.47  15198.91   7059.58   1817.98   4400.00 1.60
# 111  000150         두산  26050.00 177326.56 107525.17  39275.03  50200.00 2.14
# 579  084670       동양고속  20856.51  36502.02  28909.26   3524.14  23850.00 1.21
# 270  078520     에이블씨엔씨   5790.00  21617.33  12272.75   3405.20   7430.00 1.65
# 215  002960      한국쉘석유 206000.00 501000.00 348099.10  69409.50 250500.00 1.39
# 113  005610      SPC삼립  40650.00 239500.00 127696.78  47774.57  72700.00 1.76
# 263  004690        삼천리  56000.00 125500.00  96367.46  14753.75  79500.00 1.21
#
#        8  C/M  Max/Current
# 70  0.00 0.47         3.08
# 893 0.01 0.63         2.15
# 522 0.01 0.56         2.93
# 650 0.02 0.59         2.79
# 34  0.03 0.74         1.82
# 578 0.04 0.83         1.45
# 535 0.04 0.60         2.18
# 67  0.05 0.88         1.40
# 354 0.05 0.57         2.35
# 402 0.05 0.63         2.53
# 390 0.05 0.88         1.33
# 17  0.06 0.79         1.71
# 397 0.06 0.84         1.36
# 19  0.06 0.74         1.65
# 225 0.06 0.52         3.14
# 327 0.06 0.55         3.29
# 182 0.06 0.62         2.63
# 734 0.07 0.78         2.19
# 380 0.07 0.45         4.55
# 407 0.07 0.65         3.20
# 249 0.07 0.62         3.45
# 111 0.07 0.47         3.53
# 579 0.08 0.82         1.53
# 270 0.08 0.61         2.91
# 215 0.08 0.72         2.00
# 501 0.08 0.89         1.25
# 382 0.08 0.75         2.11
# 186 0.08 0.65         2.30
# 473 0.09 0.91         1.26
# 307 0.09 0.84         1.66
# 171 0.09 0.76         1.79
# 750 0.10 0.72         2.08
# 910 0.10 0.84         1.46
# 46  0.10 0.75         1.97
# 661 0.10 0.79         1.82
# 296 0.10 0.72         2.42
# 256 0.10 0.78         1.73
# 512 0.10 0.61         3.37
# 349 0.10 0.78         1.70
# 274 0.10 0.73         1.88
# 273 0.11 0.48         4.24
# 900 0.11 0.81         2.14
# 911 0.11 0.86         1.37
# 48  0.11 0.76         1.82
# 459 0.11 0.73         2.05
# 505 0.11 0.75         1.86
# 525 0.11 0.80         1.98
# 220 0.12 0.85         1.43
# 235 0.12 0.66         2.42
# 867 0.12 0.60         2.33
# 300 0.12 0.50         4.75
# 691 0.12 0.26        10.51
# 490 0.12 0.74         1.95
# 168 0.12 0.63         2.90
# 584 0.12 0.62         2.78
# 200 0.12 0.55         3.14
# 261 0.12 0.50         3.92
# 189 0.12 0.70         2.15
# 113 0.12 0.57         3.29
# 263 0.13 0.82         1.58

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 9340.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 13050.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-29 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       37700.0
# ChangeCode                        1
# Changes                       100.0
# ChagesRatio                     NaN
# Open                        37100.0
# High                        37800.0
# Low                         37050.0
# Volume                      74471.0
# Amount                 2788435600.0
# Marcap               238675231600.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            864
# ChangesRatio                   0.27
# Name: 11214866, dtype: object
