# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'

y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-11'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
d = df5

# %%
wuryang = d[d['Dept'] == '우량기업부']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 568

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-20-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# 91   084110    휴온스글로벌  17909.92  70335.33  37471.90  10542.99  27250.00 1.38
# 310  065510       휴비츠   5400.00  14748.76  10114.21   2401.13   7800.00 1.30
# 151  004650     창해에탄올   8880.00  22000.00  14743.62   2172.69  12650.00 1.17
# 356  049960     쎌바이오텍  10050.00  52100.00  27926.43  10506.43  18200.00 1.53
# 432  200670      휴메딕스  10650.00  43592.62  27023.70   5476.25  22000.00 1.23
# 281  222040   코스맥스엔비티   2860.00  29350.00  14460.14   7043.49   8060.00 1.79
# 61   035810     이지홀딩스   2321.65   9869.61   6076.83   1302.59   4915.00 1.24
# 443  007680        대원   5949.80  19443.75  10615.66   1594.04   9200.00 1.15
# 73   013030    하이록코리아   6800.00  32900.00  19138.52   4904.22  14800.00 1.29
# 136  007720    대명소노시즌    728.00   3750.00   2016.02    729.93   1375.00 1.47
# 289  228850      레이언스   7210.00  21800.00  15363.40   3405.14  12400.00 1.24
# 98   018120      진로발효  21100.00  41988.64  33626.20   3250.29  30850.00 1.09
# 354  041830       인바디  13500.00  50600.00  25375.00   7817.28  18700.00 1.36
# 491  148150    세경하이테크  14081.74  39550.00  25054.43   5414.53  20500.00 1.22
# 351  267980      매일유업  56600.00 101500.00  77981.92   8777.92  70600.00 1.10
# 509  289010   아이스크림에듀   6160.00  13300.00   8734.88   1159.73   7760.00 1.13
# 343  08537M   루트로닉3우C   7321.09  90978.23  36386.01  27442.46  13450.00 2.71
# 284  051500   CJ프레시웨이  11700.00  47250.00  28778.88   7922.45  22200.00 1.30
# 347  049950     미래컴퍼니  10761.84 150476.01  57701.89  31393.43  31900.00 1.81
# 5    028150     GS홈쇼핑  88600.00 245200.00 172704.18  36628.91 143200.00 1.21
# 235  039310        세중   1100.00   4820.00   3238.21    633.25   2740.00 1.18
# 171  053350       이니텍   2770.00  10700.00   6033.22   1412.62   4925.00 1.23
#
#        8  C/M
# 335 0.01 0.58
# 53  0.02 0.28
# 213 0.04 0.65
# 437 0.04 0.49
# 222 0.06 0.64
# 182 0.06 0.87
# 309 0.06 0.63
# 173 0.07 0.37
# 191 0.07 0.52
# 180 0.08 0.68
# 380 0.08 0.67
# 303 0.08 0.74
# 72  0.08 0.73
# 475 0.09 0.77
# 364 0.09 0.66
# 93  0.10 0.63
# 2   0.10 0.48
# 174 0.11 0.82
# 215 0.11 0.62
# 444 0.11 0.34
# 357 0.11 0.32
# 13  0.11 0.33
# 355 0.12 0.63
# 179 0.12 0.82
# 319 0.12 0.60
# 300 0.13 0.59
# 102 0.13 0.77
# 162 0.13 0.62
# 62  0.14 0.56
# 86  0.14 0.76
# 295 0.14 0.42
# 283 0.14 0.76
# 287 0.14 0.56
# 225 0.15 0.67
# 459 0.16 0.81
# 49  0.16 0.55
# 358 0.16 0.54
# 373 0.16 0.59
# 91  0.17 0.73
# 310 0.17 0.77
# 151 0.17 0.86
# 356 0.18 0.65
# 432 0.18 0.81
# 281 0.18 0.56
# 61  0.19 0.81
# 443 0.19 0.87
# 73  0.19 0.77
# 136 0.19 0.68
# 289 0.19 0.81
# 98  0.20 0.92
# 354 0.20 0.74
# 491 0.20 0.82
# 351 0.20 0.91
# 509 0.20 0.89
# 343 0.20 0.37
# 284 0.20 0.77
# 347 0.21 0.55
# 5   0.21 0.83
# 235 0.22 0.85
# 171 0.22 0.82

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8900.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-11 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       35350.0
# ChangeCode                        1
# Changes                       600.0
# ChagesRatio                     NaN
# Open                        34850.0
# High                        35650.0
# Low                         34650.0
# Volume                      69185.0
# Amount                 2437290200.0
# Marcap               223797597800.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            869
# ChangesRatio                   1.73
# Name: 11185633, dtype: object

# %%
df
# Out:
#                Date    Code     Name Market   Dept     Close  ChangeCode  \
# 0        1995-05-02   15760   한국전력공사  KOSPI    NaN  27400.00           2
# 1        1995-05-02    5930     삼성전자  KOSPI    NaN 119500.00           2
# 2        1995-05-02    5490   포항종합제철  KOSPI    NaN  65500.00           2
# 3        1995-05-02     200    대우중공업  KOSPI    NaN   9800.00           1
# 4        1995-05-02    2610     엘지전자  KOSPI    NaN  31700.00           2
# ...             ...     ...      ...    ...    ...       ...         ...
# 11187197 2021-03-11  009275      신원우  KOSPI    NaN  31200.00           2
# 11187198 2021-03-11  224020  에스케이씨에스  KONEX  일반기업부    910.00           3
# 11187199 2021-03-11  001529    동양3우B  KOSPI    NaN  24350.00           2
# 11187200 2021-03-11  225850      미애부  KONEX  일반기업부    350.00           2
# 11187201 2021-03-11  225860  엠앤씨생명과학  KONEX  일반기업부     70.00           1
#
#           Changes  ChagesRatio      Open      High       Low    Volume  \
# 0         -400.00        -1.44  27600.00  27800.00  27400.00 118190.00
# 1        -1000.00        -0.83 121000.00 121000.00 118500.00 139560.00
# 2         -300.00        -0.46  65800.00  66200.00  65400.00  65970.00
# 3          300.00         3.16   9500.00   9840.00   9500.00 288380.00
# 4         -300.00        -0.94  32000.00  32000.00  31700.00 171460.00
# ...           ...          ...       ...       ...       ...       ...
# 11187197   -50.00          NaN  31400.00  31400.00  31100.00    164.00
# 11187198     0.00          NaN    909.00    910.00    909.00    320.00
# 11187199  -100.00          NaN  24450.00  24450.00  23600.00    764.00
# 11187200   -61.00          NaN    350.00    350.00    350.00   5309.00
# 11187201     2.00          NaN     73.00     73.00     70.00  12122.00
#
#                  Amount            Marcap       Stocks MarketId  Rank  \
# 0         3255694000.00 16872679291000.00 615791215.00      STK     1
# 1        16676735000.00  6497053077500.00  54368645.00      STK     2
# 2         4334472000.00  6150568555000.00  93901810.00      STK     3
# 3         2805133500.00  3500638978200.00 357208059.00      STK     4
# 4         5452050000.00  2521027012200.00  79527666.00      STK     5
# ...                 ...               ...          ...      ...   ...
# 11187197     5114500.00     2831088000.00     90740.00      STK  2545
# 11187198      291000.00     2798250000.00   3075000.00      KNX  2546
# 11187199    18500700.00     2184730700.00     89722.00      STK  2547
# 11187200     1858150.00     1166316550.00   3332333.00      KNX  2549
# 11187201      871856.00      795066440.00  11358092.00      KNX  2550
#
#           ChangesRatio
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 11187197         -0.16
# 11187198          0.00
# 11187199         -0.41
# 11187200        -14.84
# 11187201          2.94
#
# [11187202 rows x 19 columns]
