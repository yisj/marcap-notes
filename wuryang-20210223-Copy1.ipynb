# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'

y1_ago = today - datetime.timedelta(days=365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y5_ago = today - datetime.timedelta(days=5*365)
y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

y1_ago = y1_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-04'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df3 = df[df['Date']>y3_ago]
df5 = df[df['Date']>y5_ago]
df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
# Out:
#                Date    Code     Name Market   Dept      Close  ChangeCode  \
# 8404392  2016-03-07  005930     삼성전자  KOSPI    NaN 1223000.00           1
# 8404393  2016-03-07  015760     한국전력  KOSPI    NaN   56800.00           2
# 8404394  2016-03-07  005380      현대차  KOSPI    NaN  146500.00           2
# 8404395  2016-03-07  028260     삼성물산  KOSPI    NaN  152500.00           2
# 8404396  2016-03-07  012330    현대모비스  KOSPI    NaN  254000.00           1
# ...             ...     ...      ...    ...    ...        ...         ...
# 10589147 2020-03-03  001799  대한제당3우B  KOSPI    NaN   20150.00           2
# 10589148 2020-03-03  001529    동양3우B  KOSPI    NaN   26350.00           2
# 10589149 2020-03-03  238500     로보쓰리  KONEX  일반기업부     478.00           1
# 10589150 2020-03-03  267810       앙츠  KONEX  일반기업부    1345.00           1
# 10589151 2020-03-03  208890    에듀파트너  KONEX  일반기업부     900.00           1
#
#           Changes  ChagesRatio       Open       High        Low     Volume  \
# 8404392   8000.00         0.66 1220000.00 1231000.00 1215000.00  131376.00
# 8404393  -1600.00        -2.74   58000.00   58200.00   56100.00 2088653.00
# 8404394  -1000.00        -0.68  147500.00  147500.00  145500.00  317439.00
# 8404395  -1500.00        -0.97  154000.00  156500.00  152500.00  345376.00
# 8404396   2500.00         0.99  252000.00  255500.00  249000.00  144983.00
# ...           ...          ...        ...        ...        ...        ...
# 10589147  -550.00        -2.66   20850.00   20850.00   20050.00    1399.00
# 10589148   -50.00        -0.19   26350.00   26350.00   25600.00    8131.00
# 10589149    48.00        11.16     486.00     486.00     367.00    2685.00
# 10589150    35.00         2.67    1345.00    1345.00    1345.00     744.00
# 10589151    50.00         5.88     900.00     900.00     900.00       5.00
#
#                   Amount             Marcap       Stocks MarketId  Rank  \
# 8404392  160439055900.00 177419799151000.00 145069337.00      STK     1
# 8404393  118161576000.00  36463559573600.00 641964077.00      STK     2
# 8404394   46423351500.00  32270504173500.00 220276479.00      STK     3
# 8404395   53025546500.00  28927731557500.00 189690043.00      STK     4
# 8404396   36620158500.00  24725341202000.00  97343863.00      STK     5
# ...                  ...                ...          ...      ...   ...
# 10589147     28272650.00      2612568400.00    129656.00      STK  2469
# 10589148    219293000.00      2364174700.00     89722.00      STK  2470
# 10589149       996142.00      2238075348.00   4682166.00      KNX  2472
# 10589150      1000680.00      2080715000.00   1547000.00      KNX  2473
# 10589151         4500.00      1935738000.00   2150820.00      KNX  2474
#
#           ChangesRatio
# 8404392            NaN
# 8404393            NaN
# 8404394            NaN
# 8404395            NaN
# 8404396            NaN
# ...                ...
# 10589147           NaN
# 10589148           NaN
# 10589149           NaN
# 10589150           NaN
# 10589151           NaN
#
# [2184760 rows x 19 columns]

# %%
d = df1_10

# %%
wuryang = d[d['Dept'] == '우량기업부']

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 864

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime('2020-03-03'):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-95-f9d031bee500>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0          1         2         3         4        5         6    7  \
# 237  054800    아이디스홀딩스  10100.00  18400.00  14640.97  1391.60  10550.00 1.39
# 156  054950      제이브이엠  21850.00  67500.00  48822.72 10108.39  22200.00 2.20
# 417  003380       하림지주   7060.00  14395.36  11205.11  1633.91   7170.00 1.56
# 46   106190       하이텍팜   9750.00  20300.00  13949.22  1632.79   9920.00 1.41
# 248  094850      참좋은여행   5190.00  16700.00   9625.48  1884.65   5210.00 1.85
# 35   095910      에스에너지   3120.00  10478.13   6937.17  1582.60   3275.00 2.12
# 263  039310         세중   2170.00   6673.81   3967.07   766.59   2210.00 1.80
# 138  078020   이베스트투자증권   4042.20  12805.15   7188.58  1025.77   4890.00 1.47
# 273  063080        게임빌  21300.00 182364.08  68786.54 27945.92  22500.00 3.06
# 60   088910    동우팜투테이블   2659.30   5221.25   3798.75   407.07   3125.00 1.22
# 496  007680         대원   9900.00  20847.03  12152.01  1365.99   9900.00 1.23
# 278  053980      오상자이엘   5350.00  23734.17  10453.73  3123.84   5350.00 1.95
# 17   036000        예림당   2790.00  15300.00   6413.77  2185.52   2850.00 2.25
# 315  081580       성우전자   2370.00   8990.00   4440.59  1150.86   2585.00 1.72
# 501  255220         SG    960.43   5483.30   3015.90   907.19   1565.00 1.93
# 67   038950      파인디지털   2800.00   9031.42   5713.91  1380.20   3510.00 1.63
# 207  005160       동국산업   2150.00   5899.22   3557.31   758.18   2355.00 1.51
# 13   123330         제닉   4000.00  41490.00  16052.15  7562.99   4120.00 3.90
# 489  260930  씨티케이코스메틱스  11000.00  46000.00  24530.07  8601.27  11000.00 2.23
# 345  039980        리노스   1165.00   4926.53   2494.99   725.56   1355.00 1.84
# 15   101390        아이엠    767.13   3271.14   1669.14   449.84    965.00 1.73
#
#        8  C/M
# 237 0.00 0.72
# 156 0.00 0.45
# 417 0.01 0.64
# 46  0.01 0.71
# 248 0.01 0.54
# 35  0.01 0.47
# 263 0.01 0.56
# 138 0.01 0.68
# 396 0.01 0.51
# 29  0.01 0.53
# 110 0.01 0.62
# 444 0.01 0.70
# 234 0.01 0.50
# 355 0.01 0.61
# 439 0.02 0.37
# 467 0.02 0.33
# 209 0.02 0.63
# 244 0.02 0.60
# 238 0.02 0.48
# 33  0.02 0.46
# 344 0.02 0.60
# 7   0.02 0.53
# 23  0.02 0.76
# 252 0.02 0.47
# 431 0.02 0.69
# 222 0.02 0.75
# 159 0.03 0.57
# 44  0.03 0.59
# 390 0.03 0.40
# 151 0.03 0.41
# 371 0.03 0.70
# 217 0.03 0.82
# 80  0.03 0.74
# 253 0.03 0.65
# 140 0.03 0.57
# 219 0.04 0.26
# 446 0.04 0.62
# 137 0.04 0.60
# 175 0.04 0.39
# 293 0.04 0.50
# 265 0.04 0.61
# 486 0.04 0.78
# 307 0.04 0.66
# 366 0.04 0.28
# 178 0.05 0.54
# 146 0.05 0.12
# 476 0.05 0.67
# 273 0.05 0.33
# 60  0.05 0.82
# 496 0.05 0.81
# 278 0.05 0.51
# 17  0.05 0.44
# 315 0.05 0.58
# 501 0.05 0.52
# 67  0.06 0.61
# 207 0.06 0.66
# 13  0.06 0.26
# 489 0.06 0.45
# 345 0.06 0.54
# 15  0.06 0.58

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8730.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12650.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-04 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       33250.0
# ChangeCode                        2
# Changes                      -100.0
# ChagesRatio                     NaN
# Open                        33250.0
# High                        33650.0
# Low                         32700.0
# Volume                      33500.0
# Amount                 1108748750.0
# Marcap               210502691000.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            931
# ChangesRatio                   -0.3
# Name: 11173550, dtype: object
