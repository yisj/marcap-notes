# %%
from marcap import marcap_data
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = marcap_data('2020-1-1', '2021-12-31')

# %%
df.columns
# Out:
# Index(['Code', 'Name', 'Market', 'Dept', 'Close', 'ChangeCode', 'Changes',
#        'ChagesRatio', 'Open', 'High', 'Low', 'Volume', 'Amount', 'Marcap',
#        'Stocks', 'MarketId', 'Rank'],
#       dtype='object')

# %%
marcap_daily = df.groupby('Date').sum()['Marcap']

# %%
marcap_daily.plot(figsize=(14,7), grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
kospi = df[df["Market"] == "KOSPI"]

# %%
kospi_daily = kospi.groupby('Date').sum()['Marcap']

# %%
kospi_daily.plot(figsize=(14,7), grid=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
min_df.head(10)
# Out:
#             Name    Close  Changes  ChagesRatio   Volume      Amount     Open  \
# Code
# 000010      조흥은행    395.0   -920.0        -15.0  14410.0  70032650.0    380.0
# 000020      동화약품   4070.0 -10800.0        -19.5    100.0   2068800.0      0.0
# 000021  동화약품(1신)  21200.0  -1700.0         -5.8     10.0    219000.0  21200.0
# 000030      상업은행    435.0  -2300.0        -15.0   3190.0  23070900.0    430.0
# 000040     KR모터스    200.0  -1100.0        -30.0     10.0     18100.0      0.0
# 000041  효성기계(1신)   8200.0  -1200.0         -7.8     10.0    141000.0   8200.0
# 000050    경    방   6850.0 -20000.0        -17.6      1.0    128500.0      0.0
# 000060      동양화재   2870.0  -5400.0        -20.9    300.0   4445000.0   2850.0
# 000070     삼 양 사   4515.0 -44500.0        -16.7    990.0  32323200.0      0.0
# 000071   삼양사(1신)  21300.0  -1700.0         -5.9     80.0   2179000.0  21200.0
#
#            High      Low        Marcap  MarcapRatio       Stocks  \
# Code
# ...

# %%
max_df = df_by_code.max()

# %%
df_by_code["Marcap"].max()['102280']
# Out:
# 450026780505.0

# %%
current_df = current_df.groupby('Code')

# %%
current_df.head(10)
# Out:
#               Code      Name     Close  Changes  ChagesRatio      Volume  \
# Date
# 2020-10-15  005930      삼성전자   60000.0   -900.0         -1.5  17756232.0
# 2020-10-15  000660    SK하이닉스   87100.0    600.0          0.7   2802900.0
# 2020-10-15  035420     NAVER  292500.0  -6000.0         -2.0    624097.0
# 2020-10-15  207940  삼성바이오로직스  704000.0  -3000.0         -0.4     67044.0
# 2020-10-15  051910      LG화학  637000.0   9000.0          1.4    531454.0
# ...            ...       ...       ...      ...          ...         ...
# 2020-10-15  000325    노루홀딩스우   17900.0    250.0          1.4      1385.0
# 2020-10-15  276240      엘리비젼     510.0     50.0         10.9        10.0
# 2020-10-15  001529     동양3우B   30200.0   1100.0          3.8      1633.0
# 2020-10-15  238500      로보쓰리     404.0     -5.0         -1.2      5790.0
# 2020-10-15  225860   엠앤씨생명과학     148.0     -1.0         -0.7         5.0
#
#                   Amount      Open      High       Low        Marcap  \
# Date
# ...

# %%
current_df[["Code", "Marcap"]].head(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-2c56d65dafe7> in <module>
# ----> 1 current_df[["Code", "Marcap"]].head(10)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1533                 stacklevel=2,
#    1534             )
# -> 1535         return super().__getitem__(key)
#    1536
#    1537     def _gotitem(self, key, ndim: int, subset=None):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/base.py in __getitem__(self, key)
#     253     def __getitem__(self, key):
#     254         if self._selection is not None:
# --> 255             raise IndexError(f"Column(s) {self._selection} already selected")
#     256
#     257         if isinstance(key, (list, tuple, ABCSeries, ABCIndexClass, np.ndarray)):
#
# ...

# %%
type(current_df)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
current_df.count().reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-0cf14be76ae8> in <module>
# ----> 1 current_df.count().reset_index()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5011                 # to ndarray and maybe infer different dtype
#    5012                 level_values = maybe_casted_values(lev, lab)
# -> 5013                 new_obj.insert(0, name, level_values)
#    5014
#    5015         new_obj.index = new_index
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3758         self._ensure_valid_index(value)
#    3759         value = self._sanitize_column(column, value, broadcast=False)
# ...
