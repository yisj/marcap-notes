# %%
import pandas as pd

# %%
from marcap import marcap_data

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

# %%
target_code = '102280'
df = marcap_data('2020-01-01', '2020-12-31')
# Out:
# cannot safely convert passed user dtype of int32 for float64 dtyped data in column 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-83152d70b11b> in <module>
#       1 target_code = '102280'
# ----> 2 df = marcap_data('2020-01-01', '2020-12-31')
#
# ~\marcap\marcap\marcap_utils.py in marcap_data(start, end, code)
#      32       print(e)
#      33       pass
# ---> 34   df_merged = pd.concat(df_list)
#      35   df_merged = df_merged[(start <= df_merged['Date']) & (df_merged['Date'] <= end)]
#      36   df_merged = df_merged.sort_values(['Date','Rank'])
#
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     283     ValueError: Indexes have overlapping values: ['a']
#     284     """
# --> 285     op = _Concatenator(
#     286         objs,
#     287         axis=axis,
#
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     340
#     341         if len(objs) == 0:
# --> 342             raise ValueError("No objects to concatenate")
#     343
#     344         if keys is None:
#
# ValueError: No objects to concatenate

# %%
plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 
ax = df['Close'].plot()
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)

# %%
latest_stocks = df.iloc[-1]['Stocks']
latest_stocks
# Out:
# 239359627.0

# %%
df.iloc[-1]
# Out:
# Code                      102280
# Name                         쌍방울
# Close                     612.00
# Changes                   -14.00
# ChagesRatio                -2.20
# Volume                2256665.00
# Amount             1389525591.00
# Open                      626.00
# High                      627.00
# Low                       610.00
# Marcap           146488091724.00
# MarcapRatio                 0.01
# Stocks              239359627.00
# ForeignShares         4711969.00
# ForeignRatio                1.97
# Rank                     1076.00
# Name: 2020-10-15 00:00:00, dtype: object

# %%
df['Adj Close'] = df['Close'] / latest_stocks * df['Stocks']

# %%
df['Adj Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Stocks'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Marcap'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['Marcap'].max()
# Out:
# 450026780505.0
