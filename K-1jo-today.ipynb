# %%
# 우량주 분석
import datetime
today=  datetime.datetime.now()

first = '1995-05-02'
m6_ago = today - datetime.timedelta(days=183)
y1_ago = today - datetime.timedelta(days=365)
y2_ago = today - datetime.timedelta(days=2*365)
y3_ago  = today  - datetime.timedelta(days=3*365)
y4_ago  = today  - datetime.timedelta(days=4*365)
y5_ago = today - datetime.timedelta(days=5*365)
y6_ago = today - datetime.timedelta(days=6*365)

y8_ago = today - datetime.timedelta(days=8*365)
y10_ago = today - datetime.timedelta(days=10*365)

today = today.strftime('%Y-%m-%d')

m6_ago = m6_ago.strftime('%Y-%m-%d')
y1_ago = y1_ago.strftime('%Y-%m-%d')
y2_ago = y2_ago.strftime('%Y-%m-%d')
y3_ago = y3_ago.strftime('%Y-%m-%d')
y4_ago = y4_ago.strftime('%Y-%m-%d')
y5_ago = y5_ago.strftime('%Y-%m-%d')
y6_ago = y6_ago.strftime('%Y-%m-%d')

y8_ago = y8_ago.strftime('%Y-%m-%d')
y10_ago = y10_ago.strftime('%Y-%m-%d')
y1_ago
# Out:
# '2020-03-15'

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data(first, today)
# Out:
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# c:\users\j\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
df['Dept'].unique()
df.reset_index(inplace=True)

# %%
df1 = df[df['Date']>y1_ago]
df2 = df[df['Date']>y2_ago]
df3 = df[df['Date']>y3_ago]
df4 = df[df['Date']>y4_ago]

df5 = df[df['Date']>y5_ago]
df6 = df[df['Date']>y6_ago]

df8 = df[df['Date']>y8_ago]
df10 = df[df['Date']>y10_ago]

df1_10 = df[df['Date']>y10_ago]
df1_10 = df1_10[df1_10['Date']<y1_ago]
df1_5 = df[df['Date']>y5_ago]
df1_5 = df1_5[df1_5['Date']<y1_ago]

# %%
dm6 = df[df['Date']>m6_ago]

# %%
d = df6
# Out:
#               Date    Code     Name Market Dept      Close  ChangeCode  \
# 7923373 2015-03-18  005930     삼성전자  KOSPI  NaN 1503000.00           1
# 7923374 2015-03-18  005380      현대차  KOSPI  NaN  182000.00           3
# 7923375 2015-03-18  000660   SK하이닉스  KOSPI  NaN   46250.00           3
# 7923376 2015-03-18  015760     한국전력  KOSPI  NaN   44750.00           1
# 7923377 2015-03-18  005935    삼성전자우  KOSPI  NaN 1128000.00           1
# 7923378 2015-03-18  012330    현대모비스  KOSPI  NaN  260000.00           1
#
#          ChangesRatio
# 7923373           NaN
# 7923374           NaN
# 7923375           NaN
# 7923376           NaN
# 7923377           NaN
# 7923378           NaN
# 7923379           NaN
# 7923380           NaN
# 7923381           NaN
# 7923382           NaN
# 7923383           NaN
# 7923384           NaN
# 7923385           NaN
# 7923386           NaN
# 7923387           NaN
# 7923388           NaN
# 7923389           NaN
# 7923390           NaN
# 7923391           NaN
# 7923392           NaN
# 7923393           NaN
# 7923394           NaN
# 7923395           NaN
# 7923396           NaN
# 7923397           NaN
# 7923398           NaN
# 7923399           NaN
# 7923400           NaN
# 7923401           NaN
# 7923402           NaN

# %%
w = d[d['Market'] == 'KOSPI']
wuryang = w[w['Marcap'] > 10000000000000]

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 295

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = d[d['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime(today):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-12-3ff44c464998>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']
wdf = pd.DataFrame(data)
wdf['C/M'] = 1 / wdf[7]
wdf.sort_values([8], ascending=[True]).head(60)
# Out:
#           0           1         2          3         4         5         6  \
# 91   000210          DL  61000.00  273824.77 187022.48  27615.80  78300.00
# 262  326030      SK바이오팜 104000.00  217000.00 163921.51  21503.73 109000.00
# 36   021240         코웨이  48250.00  118091.42  88963.99  11627.03  66700.00
# 20   033780        KT&G  63600.00  137000.00 101453.70  12275.45  80200.00
# 81   000150          두산  26050.00  177326.56 112159.25  37445.25  49300.00
# 17   000810        삼성화재 126000.00  328000.00 258808.89  40666.20 193000.00
# 231  071320      지역난방공사  26000.00   87400.00  59931.30  13876.72  37650.00
# 74   012750         에스원  73200.00  115000.00  93294.64   7314.55  81600.00
# 67   005830      DB손해보험  23800.00   83800.00  60474.75  11079.18  44550.00
# 164  037560      LG헬로비전   2420.00   14500.00   8312.78   2729.51   4535.00
# 118  057050       현대홈쇼핑  45050.00  147500.00 105972.98  21660.41  77400.00
# 186  053210      스카이라이프   4760.00   23900.00  13477.61   3856.99   8420.00
# 44   002380         KCC 107000.00  674778.55 383521.89 134745.58 207000.00
# 167  093050          LF   8940.00   36900.00  23677.45   6309.02  15950.00
# 92   001450        현대해상  17700.00   49200.00  32446.44   7183.68  23750.00
# 162  002270        롯데푸드 211500.00 1438556.90 704103.95 269438.18 378000.00
# 232  018250        애경산업  18800.00   77434.12  37299.54  14755.50  25300.00
# 41   001800      오리온홀딩스   6987.47  131057.44  43548.40  36478.84  14300.00
# 149  001430       세아베스틸   5360.00   45850.00  22739.10   8400.95  16050.00
# 194  034310        NICE  13200.00   29100.00  19216.53   2422.86  17300.00
# 98   005300        롯데칠성  72140.54  379495.62 179131.18  76935.18 121500.00
#
#        7    8  C/M
# 91  2.39 0.00 0.42
# 262 1.50 0.01 0.66
# 36  1.33 0.03 0.75
# 20  1.27 0.04 0.79
# 81  2.28 0.05 0.44
# 17  1.34 0.05 0.75
# 231 1.59 0.05 0.63
# 74  1.14 0.05 0.87
# 67  1.36 0.08 0.74
# 164 1.83 0.08 0.55
# 118 1.37 0.09 0.73
# 186 1.60 0.09 0.62
# 44  1.85 0.10 0.54
# 167 1.48 0.11 0.67
# 92  1.37 0.11 0.73
# 162 1.86 0.11 0.54
# 139 1.85 0.12 0.54
# 144 1.43 0.12 0.70
# 58  1.27 0.12 0.79
# 208 1.41 0.13 0.71
# 3   1.60 0.13 0.62
# 61  1.31 0.14 0.77
# 23  1.72 0.14 0.58
# 279 1.24 0.14 0.81
# 122 1.81 0.14 0.55
# 166 1.26 0.14 0.80
# 96  2.13 0.14 0.47
# 132 1.41 0.14 0.71
# 34  1.61 0.14 0.62
# 60  3.36 0.14 0.30
# 100 1.39 0.14 0.72
# 35  1.26 0.15 0.79
# 176 1.95 0.15 0.51
# 93  1.46 0.15 0.68
# 161 1.55 0.15 0.64
# 48  1.67 0.15 0.60
# 143 2.96 0.16 0.34
# 31  1.11 0.16 0.90
# 131 1.35 0.16 0.74
# 272 1.32 0.17 0.76
# 140 1.52 0.17 0.66
# 106 1.41 0.18 0.71
# 145 1.22 0.18 0.82
# 134 1.98 0.18 0.50
# 56  1.86 0.19 0.54
# 205 1.59 0.19 0.63
# 90  3.78 0.19 0.26
# 65  1.25 0.19 0.80
# 229 1.52 0.20 0.66
# 37  1.58 0.20 0.63
# 102 1.21 0.20 0.82
# 214 1.21 0.20 0.83
# 255 1.07 0.20 0.93
# 125 1.36 0.21 0.74
# 77  1.76 0.21 0.57
# 232 1.47 0.21 0.68
# 41  3.05 0.21 0.33
# 149 1.42 0.21 0.71
# 194 1.11 0.21 0.90
# 98  1.47 0.23 0.68

# %%
df[df['Code'] == '003380'].iloc[-1]['Close']
# Out:
# 8910.0

# %%
df[df['Code'] == '054800'].iloc[-1]['Close']
# Out:
# 12850.0

# %%
df[df['Code'] == '054950'].iloc[-1]
# Out:
# Date            2021-03-15 00:00:00
# Code                         054950
# Name                          제이브이엠
# Market                       KOSDAQ
# Dept                          우량기업부
# Close                       36300.0
# ChangeCode                        1
# Changes                       150.0
# ChagesRatio                     NaN
# Open                        36500.0
# High                        36550.0
# Low                         36100.0
# Volume                      48136.0
# Amount                 1747864300.0
# Marcap               229811960400.0
# Stocks                    6330908.0
# MarketId                        KSQ
# Rank                            862
# ChangesRatio                   0.41
# Name: 11190491, dtype: object
