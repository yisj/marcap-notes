# %%
# 우량주 분석

# %%
# 기본 모듈 로드
import pandas as pd
from marcap import marcap_data
import matplotlib.pyplot as plt

# %%
# 그래프 설정
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

plt.rcParams["figure.figsize"] = (16,4)
plt.rcParams['lines.linewidth'] = 0.5
plt.rcParams["axes.grid"] = True
plt.rcParams["axes.formatter.useoffset"] = False
plt.rcParams["xtick.minor.visible"] = True 

pd.options.display.float_format = '{:.2f}'.format

# %%
df = marcap_data('2015-01-01', '2021-02-19')

# %%
df['Dept'].unique()
# Out:
# array([nan, '우량기업부', '벤처기업부', '중견기업부', '기술성장기업부', '투자주의환기종목(소속부없음)',
#        '외국기업(소속부없음)', '일반기업부', '관리종목(소속부없음)', 'SPAC(소속부없음)', '스타트업기업부',
#        '크라우드펀딩기업부'], dtype=object)

# %%
wuryang = df[df['Dept'] == '우량기업부']
wuryang.reset_index(inplace=True)
wuryang.tail()
# Out:
#              Date    Code  Name  Market   Dept   Close  ChangeCode  Changes  \
# 494982 2021-02-19  039240  경남스틸  KOSDAQ  우량기업부 2180.00           1    85.00
# 494983 2021-02-19  081580  성우전자  KOSDAQ  우량기업부 3270.00           2   -75.00
# 494984 2021-02-19  008470   부스타  KOSDAQ  우량기업부 5840.00           2   -20.00
# 494985 2021-02-19  212560  네오오토  KOSDAQ  우량기업부 5320.00           2  -190.00
# 494986 2021-02-19  012620  원일특강  KOSDAQ  우량기업부 9480.00           2   -90.00
#
#         ChagesRatio    Open    High     Low      Volume         Amount  \
# 494982          NaN 2090.00 2550.00 2060.00 16124272.00 37782848460.00
# 494983          NaN 3315.00 3335.00 3240.00   182748.00   597021015.00
# 494984          NaN 5800.00 5890.00 5730.00    62792.00   364358130.00
# 494985          NaN 5500.00 5500.00 5250.00    65708.00   351998620.00
# 494986          NaN 9480.00 9500.00 9330.00    16360.00   154050230.00
#
#                Marcap      Stocks MarketId  Rank  ChangesRatio
# 494982 54500000000.00 25000000.00      KSQ  2060          4.06
# 494983 50711627610.00 15508143.00      KSQ  2103         -2.24
# 494984 49084032000.00  8404800.00      KSQ  2122         -0.34
# 494985 41894803160.00  7874963.00      KSQ  2199         -3.45
# 494986 41712000000.00  4400000.00      KSQ  2202         -0.94

# %%
codes = wuryang['Code'].unique()

# %%
len(codes)
# Out:
# 588

# %%
35000000/50/2
# Out:
# 350000.0

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#         Date    Code    Name Market Dept      Close  ChangeCode  Changes  \
# 0 2015-01-02  005930    삼성전자  KOSPI  NaN 1330000.00           1  3000.00
# 1 2015-01-02  005380     현대차  KOSPI  NaN  169000.00           3     0.00
# 2 2015-01-02  000660  SK하이닉스  KOSPI  NaN   47750.00           3     0.00
# 3 2015-01-02  015760    한국전력  KOSPI  NaN   42700.00           3     0.00
# 4 2015-01-02  005490   POSCO  KOSPI  NaN  283500.00           1  8000.00
#
#    ChagesRatio       Open       High        Low     Volume          Amount  \
# 0         0.23 1340000.00 1340000.00 1327000.00  175499.00 230643147000.00
# 1         0.00  169000.00  170500.00  167000.00  458014.00  77441258500.00
# 2         0.00   47950.00   48400.00   47650.00 1155944.00  55452973972.00
# 3         0.00   42350.00   42950.00   42200.00  637596.00  27145417350.00
# 4         2.90  278000.00  285000.00  277500.00  156209.00  43938855500.00
#
#               Marcap       Stocks MarketId  Rank  ChangesRatio
# 0 195908118210000.00 147299337.00      STK     1           NaN
# 1  37226724951000.00 220276479.00      STK     2           NaN
# 2  34762112928750.00 728002365.00      STK     3           NaN
# 3  27411866087900.00 641964077.00      STK     4           NaN
# 4  24717467722500.00  87186835.00      STK     5           NaN

# %%
data = list()
import scipy.stats
# for code in codes:


for code in codes:
    c = df[df['Code'] == code]
    if c['Date'].iloc[-1] == pd.to_datetime('2021-02-19'):
        latest_stocks = c['Stocks'].iloc[-1]
        c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

        c_min = c['Adj Close'].min()
        c_max = c['Adj Close'].max()
        c_mean = c['Adj Close'].mean()
        c_std = c['Adj Close'].std()

        c_current = c['Adj Close'].iloc[-1]

        c_norm = scipy.stats.norm(c_mean, c_std)

        data.append([code, c['Name'].iloc[-1], c_min, c_max, c_mean, c_std, c_current, c_mean/c_current, c_norm.cdf(c_current)])
# Out:
# <ipython-input-11-d97606c25b87>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['Adj Close'] = c['Stocks'] * c['Close'] / latest_stocks

# %%
columns = ['Code', 'Name', 'Min', 'Max', 'Mean', 'Std', 'Current', 'M/C' 'Cdf']

# %%
wdf = pd.DataFrame(data)
wdf
# Out:
#           0       1        2         3         4        5         6    7    8
# 0    035720     카카오 54297.49 514000.00 129521.84 93588.40 504000.00 0.26 1.00
# 1    068270    셀트리온 29070.28 403410.57 161485.39 87071.82 318500.00 0.51 0.96
# 2    026960      동서 14550.00  47000.00  26305.04  6621.68  42200.00 0.62 0.99
# 3    034230   파라다이스  9790.00  32300.00  17881.76  3868.38  15750.00 1.14 0.29
# 4    035760  CJ ENM 43422.44 266466.34 104386.18 63212.93 142100.00 0.73 0.72
# ..      ...     ...      ...       ...       ...      ...       ...  ...  ...
# 554  005670     푸드웰  2124.00  12960.00   5170.43  1341.09   7430.00 0.70 0.95
# 555  090410   덕신하우징   679.95   2121.04   1339.82   241.08   1670.00 0.80 0.91
# 556  032750      삼진  4930.00  15500.00   8675.54  1925.29  12800.00 0.68 0.98
# 557  086670     비엠티  3545.00  14850.00   6948.44  1930.72  14850.00 0.47 1.00
# 558  053270    구영테크   900.00   5190.00   1575.57   302.30   3755.00 0.42 1.00
#
# [559 rows x 9 columns]

# %%
wdf['C/M'] = 1 / wdf[7]

# %%
wdf
# Out:
#           0       1        2         3         4        5         6    7    8  \
